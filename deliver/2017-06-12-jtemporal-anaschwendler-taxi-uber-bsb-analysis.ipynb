# %% [markdown]
# # Taxi and Uber expenses in Brasília analysis

# %%
import pandas as pd
import numpy as np

from serenata_toolbox.datasets import fetch


fetch('2017-05-25-reimbursements.xz', '../data')
fetch('2017-05-21-companies-no-geolocation.xz', '../data') # we won't need geolocation for this analysis
# Out:
# Downloading 2017-05-25-reimbursements.xz: 100%|██████████| 34.1M/34.1M [00:03<00:00, 10.8Mb/s]
# Downloading 2017-05-21-companies-no-geolocation.xz: 100%|██████████| 7.49M/7.49M [00:00<00:00, 9.75Mb/s]

# %%
reimbursements = pd.read_csv('../data/2017-05-25-reimbursements.xz',
                             dtype={'applicant_id': np.str,
                                    'cnpj_cpf': np.str,
                                    'congressperson_id': np.str,
                                    'subquota_number': np.str},
                             low_memory=False)

# %%
companies = pd.read_csv('../data/2017-05-21-companies-no-geolocation.xz', low_memory=False)
companies['cnpj'] = companies['cnpj'].str.replace(r'\D', '')

# %% [markdown]
# For this analysis Tony wanted the `Taxi, toll and parking` reimbursements from June 2014 to the present day. Let's filter that.

# %%
reimbursements = reimbursements[reimbursements['subquota_description'] == 'Taxi, toll and parking']
reimbursements2014 = reimbursements[reimbursements['year'] == 2014]
reimbursements2014 = reimbursements2014[reimbursements2014['month'] >= 6]
reimbursementsall = reimbursements[reimbursements['year'] >= 2015]
reimbursements = reimbursements2014.append(reimbursementsall)
reimbursements.head()
# Out:
#         year applicant_id  document_id  reimbursement_value_total  \
# 981025  2014         1001      5449172                        0.0
# 981074  2014         1001      5498708                        0.0
# 981075  2014         1001      5498713                        0.0
# 981134  2014         1001      5527835                        0.0
# 981822  2014         1003      5501016                        0.0
#
#         total_net_value reimbursement_numbers congressperson_name  \
# 981025           371.68                  4709    DILCEU SPERAFICO
# 981074           458.08                  4759    DILCEU SPERAFICO
# 981075           731.48                  4759    DILCEU SPERAFICO
# 981134           628.68                  4805    DILCEU SPERAFICO
# 981822            15.00                  4760      DOMINGOS DUTRA
#
#        congressperson_id  congressperson_document    term  \
# 981025             73768                    444.0  2015.0
# 981074             73768                    444.0  2015.0
# 981075             73768                    444.0  2015.0
# 981134             73768                    444.0  2015.0
# 981822             74197                     72.0  2011.0
#
#                ...                    issue_date document_value  remark_value  \
# 981025         ...           2014-06-23 00:00:00         371.68           0.0
# 981074         ...           2014-07-23 00:00:00         458.08           0.0
# 981075         ...           2014-08-23 00:00:00         731.48           0.0
# 981134         ...           2014-10-23 00:00:00         628.68           0.0
# 981822         ...           2014-07-07 00:00:00          15.00           0.0
#
#        net_values month  installment passenger leg_of_the_trip batch_number  \
# 981025     371.68     6            0       NaN             NaN      1123351
# 981074     458.08     7            0       NaN             NaN      1136760
# 981075     731.48     8            0       NaN             NaN      1136768
# 981134     628.68    10            0       NaN             NaN      1144671
# 981822      15.00     7            0       NaN             NaN      1137401
#
#        reimbursement_values
# 981025                  0.0
# 981074                  0.0
# 981075                  0.0
# 981134                  0.0
# 981822                  0.0
#
# [5 rows x 31 columns]

# %%
reimbursements.shape
# Out:
# (71237, 31)

# %% [markdown]
# We want to find the top 500 companies we have most expenses for

# %%
aggregation = reimbursements.groupby('cnpj_cpf')['total_net_value'].agg(np.sum).rename('sum').reset_index()
top500 = aggregation.sort_values('sum', ascending=False).head(500)
top500 = top500.reset_index(drop=True)
top500.head()
# Out:
#          cnpj_cpf        sum
# 0  04088208000165  564737.65
# 1  00031708000100  507986.50
# 2  07424109000103   57065.12
# 3  37990298000134   41974.85
# 4  60537263089981   41769.60

# %%
dataset = pd.merge(top500, companies, how='left', left_on='cnpj_cpf', right_on='cnpj')
dataset = dataset.drop('cnpj', axis=1)
dataset.head()
# Out:
#          cnpj_cpf        sum additional_address_details  \
# 0  04088208000165  564737.65                        NaN
# 1  00031708000100  507986.50        BL. A SALAS 1,2 E 3
# 2  07424109000103   57065.12                SALA 16 SLJ
# 3  37990298000134   41974.85                        NaN
# 4  60537263089981   41769.60                        NaN
#
#                                              address  capital_social  \
# 0                                   R MINAS BOGASIAN     99863241.68
# 1                               SHC/SUL SQ PLL PARTE            0.00
# 2                            Q SCS QUADRA 05 BLOCO C            0.00
# 3                     Q SCS QD. 01 BLOCO K SALA 1202            0.00
# 4  AER INTERNACIONAL DE BRASILIA - P. JUSCELINO K...            0.00
#
#        city email extra              last_updated  \
# 0    OSASCO   NaN    {}  2017-02-01T10:16:54.823Z
# 1  BRASILIA   NaN    {}  2017-03-23T00:24:04.647Z
# 2  BRASILIA   NaN    {}  2017-03-07T06:16:25.841Z
# 3  BRASILIA   NaN    {}  2017-03-25T09:40:57.773Z
# 4  BRASILIA   NaN    {}  2017-02-19T14:10:19.999Z
#
#                             legal_entity     ...     situation situation_date  \
# 0  206-2 - Sociedade Empresária Limitada     ...         ATIVA     09/10/2000
# 1              313-1 - Entidade Sindical     ...         ATIVA     03/11/2005
# 2              313-1 - Entidade Sindical     ...         ATIVA     01/06/2005
# 3  206-2 - Sociedade Empresária Limitada     ...         ATIVA     03/11/2005
# 4      205-4 - Sociedade Anônima Fechada     ...         ATIVA     28/04/2014
#
#   situation_reason special_situation special_situation_date state status  \
# 0              NaN               NaN                    NaN    SP     OK
# 1              NaN               NaN                    NaN    DF     OK
# 2              NaN               NaN                    NaN    DF     OK
# 3              NaN               NaN                    NaN    DF     OK
# 4              NaN               NaN                    NaN    DF     OK
#
#                                          trade_name    type    zip_code
# 0                                               NaN  MATRIZ  06.013-010
# 1                                         SINPETAXI  MATRIZ  70.338-080
# 2                                           SINTAXI  MATRIZ  70.305-000
# 3                               RADIO TAXI ALVORADA  MATRIZ  70.398-900
# 4  ALLPARK EMPREENDIMENTOS PARTICIPACOES E SERVICOS  FILIAL  71.608-900
#
# [5 rows x 405 columns]

# %%
dataset.shape
# Out:
# (500, 405)

# %% [markdown]
# ## Further investigation
#
# With that table we selected a few companies and apps for further investigation:
#
# 1. Companies
#    1. CGMP CENTRO DE GESTAO DE MEIOS DE PAGAMENTO LTDA - CNPJ: 04088208000165
#    1. SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTORISTAS AUXILIARES DO DISTRITO FEDERAL - CNPJ: 00031708000100
#    1. SINDICATO DOS TAXISTAS DO DISTRITO FEDERAL- SINTAXI - CNPJ: 7424109000103
#    1. RADIO TAXI ALVORADA LTDA - ME - CNPJ: 37990298000134
#    1. ALLPARK EMPREENDIMENTOS, PARTICIPACOES E SERVICOS S.A. - CNPJ: 60537263089981
# 1. APPS
#    1. 99 TAXIS LLC - CNPJ: 18533324000150
#    1. 99 TAXIS DESENVOLVIMENTO DE SOFTWARES LTDA. - CNPJ: 18033552000161
#    1. EASY TAXI SERVICOS LTDA. - CNPJ: 16809351000188
#    1. UBER DO BRASIL TECNOLOGIA LTDA. - CNPJ: 17895646000187
#
#
# We want to know the top 5 lower house representatives with most expenses in those CNPJs and how many expenses where there.

# %%
cnpjs = ['04088208000165', '00031708000100', '7424109000103',  '37990298000134', '60537263089981',
         '18533324000150', '18033552000161', '16809351000188', '17895646000187']
reimbursements = reimbursements[reimbursements['cnpj_cpf'].isin(cnpjs)]
reimbursements.head()
# Out:
#         year applicant_id  document_id  reimbursement_value_total  \
# 981025  2014         1001      5449172                        0.0
# 981074  2014         1001      5498708                        0.0
# 981075  2014         1001      5498713                        0.0
# 981134  2014         1001      5527835                        0.0
# 981822  2014         1003      5501016                        0.0
#
#         total_net_value reimbursement_numbers congressperson_name  \
# 981025           371.68                  4709    DILCEU SPERAFICO
# 981074           458.08                  4759    DILCEU SPERAFICO
# 981075           731.48                  4759    DILCEU SPERAFICO
# 981134           628.68                  4805    DILCEU SPERAFICO
# 981822            15.00                  4760      DOMINGOS DUTRA
#
#        congressperson_id  congressperson_document    term  \
# 981025             73768                    444.0  2015.0
# 981074             73768                    444.0  2015.0
# 981075             73768                    444.0  2015.0
# 981134             73768                    444.0  2015.0
# 981822             74197                     72.0  2011.0
#
#                ...                    issue_date document_value  remark_value  \
# 981025         ...           2014-06-23 00:00:00         371.68           0.0
# 981074         ...           2014-07-23 00:00:00         458.08           0.0
# 981075         ...           2014-08-23 00:00:00         731.48           0.0
# 981134         ...           2014-10-23 00:00:00         628.68           0.0
# 981822         ...           2014-07-07 00:00:00          15.00           0.0
#
#        net_values month  installment passenger leg_of_the_trip batch_number  \
# 981025     371.68     6            0       NaN             NaN      1123351
# 981074     458.08     7            0       NaN             NaN      1136760
# 981075     731.48     8            0       NaN             NaN      1136768
# 981134     628.68    10            0       NaN             NaN      1144671
# 981822      15.00     7            0       NaN             NaN      1137401
#
#        reimbursement_values
# 981025                  0.0
# 981074                  0.0
# 981075                  0.0
# 981134                  0.0
# 981822                  0.0
#
# [5 rows x 31 columns]

# %%
keys = ['congressperson_name', 'cnpj_cpf']

reimbursements_agg = reimbursements.groupby(keys)['total_net_value'] \
                                   .agg([np.sum, len]).rename(columns={'len':'expenses'})
reimbursements_agg.head(20)
# Out:
#                                          sum  expenses
# congressperson_name  cnpj_cpf
# ACELINO POPÓ         00031708000100   155.00       3.0
#                      37990298000134    90.00       1.0
#                      60537263089981    12.00       1.0
# ADAIL CARNEIRO       00031708000100   206.00      10.0
#                      16809351000188    35.00       1.0
#                      60537263089981    14.00       1.0
# ADELMO CARNEIRO LEÃO 00031708000100  8098.96     355.0
#                      16809351000188    32.00       1.0
#                      37990298000134   237.79      11.0
#                      60537263089981    32.40       1.0
# ADEMIR CAMILO        00031708000100   100.00       2.0
#                      16809351000188    62.10       2.0
#                      60537263089981   100.00       5.0
# ADILTON SACHETTI     00031708000100   885.55      25.0
#                      37990298000134    42.00       1.0
# ADRIAN               00031708000100    60.00       1.0
# ADÉRMIS MARINI       00031708000100   262.00      10.0
#                      04088208000165  1215.02       3.0
#                      17895646000187   378.49      15.0
# AELTON FREITAS       00031708000100   540.00      20.0

# %%
reimbursements_agg = reimbursements_agg.reset_index()
reimbursements_agg.head()
# Out:
#   congressperson_name        cnpj_cpf    sum  expenses
# 0        ACELINO POPÓ  00031708000100  155.0       3.0
# 1        ACELINO POPÓ  37990298000134   90.0       1.0
# 2        ACELINO POPÓ  60537263089981   12.0       1.0
# 3      ADAIL CARNEIRO  00031708000100  206.0      10.0
# 4      ADAIL CARNEIRO  16809351000188   35.0       1.0

# %%
reimbursements_agg.shape
# Out:
# (768, 4)

# %%
companies = companies[['name', 'cnpj']]
companies.head(20)
# Out:
#                                                  name            cnpj
# 0                                     IVO M DIAS - ME  04636932000186
# 1                      POSTO DE SERVICO CAMBOATA LTDA  28232643000180
# 2                        AUTO POSTO PRINCIPE III LTDA  18005070000106
# 3   ACELE - TREINAMENTO, ASSESSORIA E CONSULTORIA ...  17793398000163
# 4                      CAIRU AUTO CENTER EIRELI - EPP  32021479000139
# 5                               LOJAS AMERICANAS S.A.  33014556037600
# 6   POSTO DE GASOLINA SAO SEBASTIAO DE BELFORD ROX...  36562874000180
# 7                         RSO COMUNICACAO EIRELI - ME  22939818000107
# 8         SOCIEDADE RADIO VALE DO JAGUARIBE LTDA - ME  07623838000180
# 9              AROS COMERCIO DE ALIMENTOS LTDA. - EPP  13917439000125
# 10               T2M DO BRASIL DISTRIBUIDOR LTDA - ME  11201924000172
# 11                  POSTO DAS DUNAS DE CABO FRIO LTDA  28746667000157
# 12                      MAZZUTTI & SEGATTO LTDA - EPP  04229718000105
# 13                       MMC CONVENIENCIA EIRELI - ME  22469255000130
# 14             A.M. DA FONSECA CONVENIENCIA LTDA - ME  19599910000160
# 15                    HOTEL POUSADA CRYSTAL LTDA - ME  08270638000154
# 16                          BRANDAO EDITORA LTDA - ME  07861343000190
# 17                         YARA RESTAURANTE LTDA - ME  17236136000106
# 18               E CARVALHO COMERCIO E NAVEGACAO LTDA  04780565000513
# 19                           CALTUR TURISMO LTDA - ME  05782333000133

# %%
dataset = pd.merge(reimbursements_agg, companies, right_on='cnpj', left_on='cnpj_cpf')
dataset = dataset.drop('cnpj', axis=1)
dataset.head(20)
# Out:
#      congressperson_name        cnpj_cpf       sum  expenses  \
# 0           ACELINO POPÓ  00031708000100    155.00       3.0
# 1         ADAIL CARNEIRO  00031708000100    206.00      10.0
# 2   ADELMO CARNEIRO LEÃO  00031708000100   8098.96     355.0
# 3          ADEMIR CAMILO  00031708000100    100.00       2.0
# 4       ADILTON SACHETTI  00031708000100    885.55      25.0
# 5                 ADRIAN  00031708000100     60.00       1.0
# 6         ADÉRMIS MARINI  00031708000100    262.00      10.0
# 7         AELTON FREITAS  00031708000100    540.00      20.0
# 8        AFONSO FLORENCE  00031708000100   2574.00      63.0
# 9           AFONSO MOTTA  00031708000100    130.62       4.0
# 10             ALAN RICK  00031708000100     62.00       1.0
# 11      ALESSANDRO MOLON  00031708000100  28513.10     691.0
# 12       ALEXANDRE BALDY  00031708000100    406.03      18.0
# 13       ALEXANDRE LEITE  00031708000100   1247.73      36.0
# 14        ALEXANDRE ROSO  00031708000100    571.95      24.0
# 15   ALEXANDRE SERFIOTIS  00031708000100     90.00       1.0
# 16    ALEXANDRE SILVEIRA  00031708000100   2257.00      60.0
# 17        ALFREDO SIRKIS  00031708000100    155.00       2.0
# 18        ALICE PORTUGAL  00031708000100     40.00       1.0
# 19         ALIEL MACHADO  00031708000100   5774.00     171.0
#
#                                                  name
# 0   SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTOR...
# 1   SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTOR...
# 2   SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTOR...
# 3   SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTOR...
# 4   SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTOR...
# 5   SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTOR...
# 6   SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTOR...
# 7   SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTOR...
# 8   SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTOR...
# 9   SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTOR...
# 10  SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTOR...
# 11  SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTOR...
# 12  SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTOR...
# 13  SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTOR...
# 14  SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTOR...
# 15  SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTOR...
# 16  SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTOR...
# 17  SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTOR...
# 18  SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTOR...
# 19  SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTOR...

# %%
dataset.shape
# Out:
# (768, 5)

# %%
dataset = dataset.sort_values(['sum', 'expenses'], ascending=[False, False]).reset_index(drop=True)
dataset.head()
# Out:
#   congressperson_name        cnpj_cpf       sum  expenses  \
# 0         ZECA DIRCEU  00031708000100  36916.73    1136.0
# 1   MARCELO SQUASSONI  04088208000165  36553.56      24.0
# 2    ALESSANDRO MOLON  00031708000100  28513.10     691.0
# 3  FRANCISCO FLORIANO  04088208000165  27596.54      31.0
# 4    VANDERLEI MACRIS  04088208000165  25612.84      17.0
#
#                                                 name
# 0  SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTOR...
# 1   CGMP CENTRO DE GESTAO DE MEIOS DE PAGAMENTO LTDA
# 2  SINDICATO DOS PERMISSIONARIOS DE TAXIS E MOTOR...
# 3   CGMP CENTRO DE GESTAO DE MEIOS DE PAGAMENTO LTDA
# 4   CGMP CENTRO DE GESTAO DE MEIOS DE PAGAMENTO LTDA

# %%
# writer = pd.ExcelWriter('taxi-analysis.xlsx') # requires openpyxl
# dataset.to_excel(writer,'Sheet1')
# writer.save()
