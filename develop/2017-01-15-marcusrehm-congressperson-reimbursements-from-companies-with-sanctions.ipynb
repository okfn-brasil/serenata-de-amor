# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Reimbursements
#
# This notebook crosses the **CEIS** dataset which gather companies with some type of problem with Federal spheres and reimbursements related to **CEAP**.

# %%
reimbursements = pd.read_csv('../data/2016-08-08-current-year.xz',
                                              dtype={'cnpj_cpf': np.str,
                                                     'document_id': np.str,
                                                     'reimbursement_value': np.float},
                                              parse_dates = ['issue_date'], 
                                              low_memory=False)
reimbursements.shape
# Out:
# (185459, 29)

# %%
reimbursements.iloc[1]
# Out:
# document_id                                                             5970849
# congressperson_name                                           ABEL MESQUITA JR.
# congressperson_id                                                        178957
# congressperson_document                                                       1
# term                                                                       2015
# state                                                                        RR
# party                                                                       DEM
# term_id                                                                      55
# subquota_number                                                               1
# subquota_description          Maintenance of office supporting parliamentary...
# subquota_group_id                                                             0
# subquota_group_description                                                  NaN
# supplier                                COMPANHIA DE AGUAS E ESGOTOS DE RORAIMA
# cnpj_cpf                                                         05939467000115
# document_number                                                          146439
# document_type                                                                 0
# issue_date                                                  2016-03-12 00:00:00
# document_value                                                            38.84
# remark_value                                                                1.6
# net_value                                                                 37.24
# month                                                                         3
# year                                                                       2016
# installment                                                                   0
# passenger                                                                   NaN
# leg_of_the_trip                                                             NaN
# batch_number                                                            1282185
# reimbursement_number                                                       5417
# reimbursement_value                                                         NaN
# applicant_id                                                               3074
# Name: 1, dtype: object

# %% [markdown]
# ---
# ## Inident and Suspended Companies - CEIS
#
# This dataset gather companies and individuals who have suffered sanctions by the organs and entities of the public administration of the various federative spheres.
#
# Origin of the information: Controladoria-Geral da União - CGU (Comptroller General of the Union)

# %%
inident_and_suspended_companies = pd.read_csv('../data/2016-12-21-inident-and-suspended-companies.xz',
                                              dtype={'sanctioned_cnpj_cpf': np.str,
                                                     'process_number': np.str},
                                              parse_dates = ['sanction_start_date',
                                                             'sanction_end_date', 
                                                             'data_source_date',
                                                             'published_date'], 
                                              low_memory=False)
inident_and_suspended_companies.fillna('', inplace=True)
inident_and_suspended_companies['sanction_start_date'] = pd.to_datetime(
                            inident_and_suspended_companies['sanction_start_date'], 
                            format='%Y-%m-%d')
inident_and_suspended_companies['sanction_end_date'] = pd.to_datetime(
                            inident_and_suspended_companies['sanction_end_date'],
                            format='%Y-%m-%d')
inident_and_suspended_companies.shape
# Out:
# (13084, 17)

# %%
inident_and_suspended_companies.iloc[0]
# Out:
# entity_type                                                                            Física
# sanctioned_cnpj_cpf                                                                1540142817
# name_given_by_sanctioning_body                                                    01540142817
# company_name_receita_database                                               FAIAD HABIB ZAKIR
# trading_name_receita_database
# process_number                                                           00001655520138260240
# sanction_type                                                  Proibição - Lei de Improbidade
# sanction_start_date                                                       2014-08-09 00:00:00
# sanction_end_date                                                         2019-08-09 00:00:00
# sanctioning_body                            Tribunal de Justiça do Estado de São Paulo / 1...
# state_of_sanctioning_body                                                                  SP
# data_source                                                      Conselho Nacional de Justiça
# data_source_date                                                          2015-08-05 00:00:00
# published_date
# publication
# detailing
# Abrangência definida em decisão judicial
# Name: 0, dtype: object

# %% [markdown]
# #### Querying the reimbursements from companies suspended
#
# Below we have a list of reibursements from dates where the suplier is listed in CEIS dataset.

# %%
reimbursements_from_inident_companies = reimbursements.merge(
                                        inident_and_suspended_companies, 
                                        left_on='cnpj_cpf', 
                                        right_on='sanctioned_cnpj_cpf')
reimbursements_from_inident_companies.shape
# Out:
# (44, 46)

# %% [markdown]
# Now from the selected reimbursements, we get only the ones made between time the saction is valid.

# %%
suspect_reimbursements = reimbursements_from_inident_companies.query(
                                           'sanction_start_date <= issue_date and \
                                           issue_date <= sanction_end_date')
suspect_reimbursements.shape
# Out:
# (16, 46)

# %%
suspect_reimbursements.filter([ 'document_id',
                                'congressperson_name',
                                'congressperson_id',
                                'congressperson_document',
                                'term',
                                'subquota_description',
                                'subquota_group_description',
                                'supplier',
                                'cnpj_cpf',
                                'document_number',
                                'document_type',
                                'issue_date',
                                'document_value',
                                'name_given_by_sanctioning_body',
                                'company_name_receita_database', 
                                'trading_name_receita_database',
                                'process_number', 
                                'sanction_type', 
                                'sanction_start_date',
                                'sanction_end_date', 
                                'sanctioning_body'])
# Out:
#    document_id       congressperson_name  congressperson_id  \
# 0      5914601         ABEL MESQUITA JR.           178957.0
# 1      5931084             REMÍDIO MONAI           178960.0
# 3      5982793             ADEMIR CAMILO           133374.0
# 4      5982793             ADEMIR CAMILO           133374.0
# 5      6045571             ANGELA ALBINO           192120.0
# 6      5972071            CELSO MALDANER           141405.0
# 7      5972059            CELSO MALDANER           141405.0
# 31     5901395             MARCOS MONTES           141500.0
# 32     5986940             MARCOS MONTES           141500.0
# 33     6010353             MARCOS MONTES           141500.0
# 34     6046147               ODELMO LEÃO            74752.0
# 36     5970425               ODELMO LEÃO            74752.0
# 37     5995066               ODELMO LEÃO            74752.0
# 38     6012145               ODELMO LEÃO            74752.0
# 39     6021101               ODELMO LEÃO            74752.0
# 42     5979304  ROGÉRIO PENINHA MENDONÇA           160651.0
#
#     congressperson_document  term  \
# 0                       1.0  2015
# 1                       7.0  2015
# 3                     520.0  2015
# 4                     520.0  2015
# 5                     559.0  2015
# 6                     472.0  2015
# 7                     472.0  2015
# 31                    257.0  2015
# 32                    257.0  2015
# 33                    257.0  2015
# 34                    248.0  2015
# 36                    248.0  2015
# 37                    248.0  2015
# 38                    248.0  2015
# 39                    248.0  2015
# 42                    483.0  2015
#
#                                  subquota_description  \
# 0            Consultancy, research and technical work
# 1                 Publicity of parliamentary activity
# 3                                 Congressperson meal
# 4                                 Congressperson meal
# 5           Terrestrial, maritime and fluvial tickets
# 6                       Watercraft renting or charter
# 7                       Watercraft renting or charter
# 31  Maintenance of office supporting parliamentary...
# 32  Maintenance of office supporting parliamentary...
# 33  Maintenance of office supporting parliamentary...
# 34  Maintenance of office supporting parliamentary...
# 36   Security service provided by specialized company
# 37   Security service provided by specialized company
# 38   Security service provided by specialized company
# 39   Security service provided by specialized company
# 42  Maintenance of office supporting parliamentary...
#
#    subquota_group_description                                supplier  \
# 0                         NaN       EFZ COMERCIO E REPRESENTAÇÃO LTDA
# 1                         NaN       EFZ COMERCIO E REPRESENTAÇÃO LTDA
# 3                         NaN         Reis & Acquaviva Comércio Ltda.
# 4                         NaN         Reis & Acquaviva Comércio Ltda.
# 5                         NaN          REUNIDAS TRANSPORTES COLETIVOS
# 6                         NaN          REUNIDAS TRANSPORTES COLETIVOS
# 7                         NaN          REUNIDAS TRANSPORTES COLETIVOS
# 31                        NaN              JEREMAIS RAIMUNDO VENANCIO
# 32                        NaN              JEREMAIS RAIMUNDO VENANCIO
# 33                        NaN              JEREMAIS RAIMUNDO VENANCIO
# 34                        NaN  ATIVA ALARMES MONITORAMENTO 24 HS LTDA
# 36                        NaN  ATIVA ALARMES MONITORAMENTO 24 HS LTDA
# 37                        NaN  ATIVA ALARMES MONITORAMENTO 24 HS LTDA
# 38                        NaN  ATIVA ALARMES MONITORAMENTO 24 HS LTDA
# 39                        NaN  ATIVA ALARMES MONITORAMENTO 24 HS LTDA
# 42                        NaN         ALIANÇA PAPELARIA E INFORMÁTICA
#
#           cnpj_cpf document_number  \
# 0   16923719000134            2061
# 1   16923719000134            2076
# 3   14954288000148          224070
# 4   14954288000148          224070
# 5   83054395000132          094743
# 6   83054395000132          777393
# 7   83054395000132          777394
# 31     64183858615         01/2016
# 32     64183858615              sn
# 33     64183858615              sn
# 34  14518825000107        00001586
# 36  14518825000107        00001483
# 37  14518825000107        00001529
# 38  14518825000107        00001537
# 39  14518825000107        00001548
# 42  18960182000108            3298
#
#                           ...                          issue_date  \
# 0                         ...                          2016-02-17
# 1                         ...                          2016-03-03
# 3                         ...                          2016-03-12
# 4                         ...                          2016-03-12
# 5                         ...                          2016-06-27
# 6                         ...                          2016-04-09
# 7                         ...                          2016-04-10
# 31                        ...                          2016-02-01
# 32                        ...                          2016-05-02
# 33                        ...                          2016-05-31
# 34                        ...                          2016-07-08
# 36                        ...                          2016-04-12
# 37                        ...                          2016-05-08
# 38                        ...                          2016-05-30
# 39                        ...                          2016-05-06
# 42                        ...                          2016-04-27
#
#    document_value                    name_given_by_sanctioning_body  \
# 0        20000.00                EFZ COMÉRCIO E REPRESENTAÇÕES LTDA
# 1        15000.00                EFZ COMÉRCIO E REPRESENTAÇÕES LTDA
# 3           28.00                       POUSO ALEGRE FOODS LTDA. ME
# 4           28.00                       POUSO ALEGRE FOODS LTDA. ME
# 5           45.75            Reunidas S.A. Transportes de Coletivos
# 6           51.93            Reunidas S.A. Transportes de Coletivos
# 7          111.35            Reunidas S.A. Transportes de Coletivos
# 31        1200.00                        JEREMIAS RAIMUNDO VENâNCIO
# 32        1200.00                        JEREMIAS RAIMUNDO VENâNCIO
# 33        1200.00                        JEREMIAS RAIMUNDO VENâNCIO
# 34         154.00         Ativa Alarmes e Monitoramento 24 hs. Ltda
# 36         154.00         Ativa Alarmes e Monitoramento 24 hs. Ltda
# 37         154.00         Ativa Alarmes e Monitoramento 24 hs. Ltda
# 38        2527.00         Ativa Alarmes e Monitoramento 24 hs. Ltda
# 39         154.00         Ativa Alarmes e Monitoramento 24 hs. Ltda
# 42          26.80  ALIANÇA COMÉRCIO DE PAPELARIA E INFORMÁTICA - ME
#
#                       company_name_receita_database  \
# 0          EFZ COMERCIO E REPRESENTACAO EIRELI - ME
# 1          EFZ COMERCIO E REPRESENTACAO EIRELI - ME
# 3                     POUSO ALEGRE FOODS LTDA  - ME
# 4                     POUSO ALEGRE FOODS LTDA  - ME
# 5                REUNIDAS S A TRANSPORTES COLETIVOS
# 6                REUNIDAS S A TRANSPORTES COLETIVOS
# 7                REUNIDAS S A TRANSPORTES COLETIVOS
# 31                       JEREMIAS RAIMUNDO VENANCIO
# 32                       JEREMIAS RAIMUNDO VENANCIO
# 33                       JEREMIAS RAIMUNDO VENANCIO
# 34  ATIVA ALARMES E MONITORAMENTO 24 HRS LTDA - EPP
# 36  ATIVA ALARMES E MONITORAMENTO 24 HRS LTDA - EPP
# 37  ATIVA ALARMES E MONITORAMENTO 24 HRS LTDA - EPP
# 38  ATIVA ALARMES E MONITORAMENTO 24 HRS LTDA - EPP
# 39  ATIVA ALARMES E MONITORAMENTO 24 HRS LTDA - EPP
# 42        ALIANCA COMERCIO DE PAPELARIA EIRELI - ME
#
#          trading_name_receita_database           process_number  \
# 0                   A ! REPRESENTACOES          (não informado)
# 1                   A ! REPRESENTACOES          (não informado)
# 3                  SUBWAY POUSO ALEGRE     10831.722122/2014-35
# 4                  SUBWAY POUSO ALEGRE     10814.729285/2014-57
# 5                                          50500.044460/2009-23
# 6                                          50500.044460/2009-23
# 7                                          50500.044460/2009-23
# 31                                                0040090953387
# 32                                                0040090953387
# 33                                                0040090953387
# 34  ATIVA ALARMES MONITORAMENTO 24 HRS  17615-45.2015.4.01.8008
# 36  ATIVA ALARMES MONITORAMENTO 24 HRS  17615-45.2015.4.01.8008
# 37  ATIVA ALARMES MONITORAMENTO 24 HRS  17615-45.2015.4.01.8008
# 38  ATIVA ALARMES MONITORAMENTO 24 HRS  17615-45.2015.4.01.8008
# 39  ATIVA ALARMES MONITORAMENTO 24 HRS  17615-45.2015.4.01.8008
# 42                   ALIANCA PAPELARIA       08190.047787/15-53
#
#                          sanction_type sanction_start_date sanction_end_date  \
# 0        Suspensão - Lei de Licitações          2015-11-30        2017-11-29
# 1        Suspensão - Lei de Licitações          2015-11-30        2017-11-29
# 3        Suspensão - Lei de Licitações          2015-12-18        2017-12-17
# 4        Suspensão - Lei de Licitações          2015-01-23        2017-01-22
# 5   Inidoneidade - Lei da ANTT e ANTAQ          2014-10-15        2017-10-14
# 6   Inidoneidade - Lei da ANTT e ANTAQ          2014-10-15        2017-10-14
# 7   Inidoneidade - Lei da ANTT e ANTAQ          2014-10-15        2017-10-14
# 31      Proibição - Lei de Improbidade          2015-12-16        2018-12-16
# 32      Proibição - Lei de Improbidade          2015-12-16        2018-12-16
# 33      Proibição - Lei de Improbidade          2015-12-16        2018-12-16
# 34       Suspensão - Lei de Licitações          2016-03-30        2018-03-29
# 36       Suspensão - Lei de Licitações          2016-03-30        2018-03-29
# 37       Suspensão - Lei de Licitações          2016-03-30        2018-03-29
# 38       Suspensão - Lei de Licitações          2016-03-30        2018-03-29
# 39       Suspensão - Lei de Licitações          2016-03-30        2018-03-29
# 42       Suspensão - Lei de Licitações          2015-12-24        2016-12-23
#
#                                      sanctioning_body
# 0                   FUNDAÇÃO UNIVERSIDADE DE BRASÍLIA
# 1                   FUNDAÇÃO UNIVERSIDADE DE BRASÍLIA
# 3                           Receita Federal do Brasil
# 4                           Receita Federal do Brasil
# 5          AGÊNCIA NACIONAL DE TRANSPORTES TERRESTRES
# 6          AGÊNCIA NACIONAL DE TRANSPORTES TERRESTRES
# 7          AGÊNCIA NACIONAL DE TRANSPORTES TERRESTRES
# 31  Tribunal de Justiça do Estado de Minas Gerais ...
# 32  Tribunal de Justiça do Estado de Minas Gerais ...
# 33  Tribunal de Justiça do Estado de Minas Gerais ...
# 34                    Justiça Federal de Minas Gerais
# 36                    Justiça Federal de Minas Gerais
# 37                    Justiça Federal de Minas Gerais
# 38                    Justiça Federal de Minas Gerais
# 39                    Justiça Federal de Minas Gerais
# 42             MINISTÉRIO PÚBLICO DO DF E TERRITÓRIOS
#
# [16 rows x 21 columns]

# %% [markdown]
# The study above doesnt prove anything ilegal, but at least the congressperson should have research about the company before use its services.
