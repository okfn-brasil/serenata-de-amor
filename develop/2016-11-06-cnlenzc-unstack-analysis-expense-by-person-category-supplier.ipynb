# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../data/2016-11-19-reimbursements.xz',
                   parse_dates=[16],
                   dtype={'document_id': np.str,
                          'congressperson_id': np.str,
                          'congressperson_document': np.str,
                          'term_id': np.str,
                          'cnpj_cpf': np.str,
                          'reimbursement_number': np.str},
                   low_memory=False)
data = data[data['year'] == 2016]

# %% [markdown]
# # analise de despesas por deputado X categoria

# %%
data_filtro = data[\
((data.party == 'PT')\
 | (data.party == 'PMDB')\
 | (data.party == 'PSDB'))\
& ((data.state == 'SP')\
 | (data.state == 'RJ'))\
& ((data.subquota_number == 5)\
 | (data.subquota_number == 999)\
 | (data.subquota_number == 120)\
 | (data.subquota_number == 13))]

tot = \
data_filtro.groupby(['party', 'state', 'applicant_id', 'congressperson_name', 'subquota_description'])\
.aggregate({'total_net_value': np.sum})

tot.unstack(-1)
# Out:
#                                                                    total_net_value  \
# subquota_description                         Automotive vehicle renting or charter
# party state applicant_id congressperson_name
# PMDB  RJ    1118         LAURA CARNEIRO                                        NaN
#             1467         CELSO JACOB                                      37061.07
#             1583         LEONARDO PICCIANI                                     NaN
#             2331         WASHINGTON REIS                                  67000.00
#             2386         PEDRO PAULO                                      16007.50
#             2429         FERNANDO JORDÃO                                  58500.00
#             2922         SORAYA SANTOS                                         NaN
#             2963         CELSO PANSERA                                         NaN
#             3005         ALTINEU CÔRTES                                        NaN
# ...

# %%
data_filtro = data[(data.subquota_number == 999)]

tot = \
   data_filtro.groupby(['party', 'state', 'congressperson_name', 'subquota_description', 'month'])\
   .aggregate({'total_net_value': np.sum})

tot.unstack()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
data_filtro = data[(data.subquota_number == 999)]

tot = \
   data_filtro.groupby(['cnpj_cpf', 'supplier', 'subquota_description', 'month'])\
   .aggregate({'total_net_value': np.sum})

tot.unstack()
# Out:
# Empty DataFrame
# Columns: []
# Index: []
