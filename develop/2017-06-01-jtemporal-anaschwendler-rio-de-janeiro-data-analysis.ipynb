# %% [markdown]
# # Rio de Janeiro data study
#
# With this notebook we aim to assess whether Rio de Janeiro's data is ready to be used.
# Documentation on Rio's data used in this notebook can be found [here](http://dadosabertos.rio.rj.gov.br/apiRioTransparente/apresentacao/pdf/documentacao_despesas.pdf).

# %%
from urllib.request import urlretrieve
import pandas as pd


data_url = 'http://dadosabertos2.rio.rj.gov.br/dadoaberto/ws/riotransparente/csv/despesa/2016'

file_path = '../data/riotransparente.csv'

urlretrieve(data_url, file_path)
data = pd.read_csv(file_path)

# %%
data.head()
# Out:
#    Exercicio  Orgao  Unidade_Orcamentaria  Programa_de_Trabalho  Acao  \
# 0       2016     11                     1     11010412203032771  2771
# 1       2016     11                     1     11010412203041726  1726
# 2       2016     11                     1     11010412203042603  2603
# 3       2016     11                     1     11010412203042603  2603
# 4       2016     11                     1     11010412203762706  2706
#
#                                       Descricao_Acao  Fonte_de_Recursos  \
# 0          APOIO A AUTORIDADE PUBLICA OLIMPICA - APO                100
# 1  PROJETO DE REVITALIZACAO DO CAIS DO PORTO DO R...                100
# 2   REVITALIZACAO DO CAIS DO PORTO DO RIO DE JANEIRO                100
# 3   REVITALIZACAO DO CAIS DO PORTO DO RIO DE JANEIRO                100
# 4                CENTRAL UNICA DE ATENDIMENTO - 1746                100
#
#                    Descricao_Fonte  Elemento_Despesa  \
# 0  100 - ORDINARIOS NAO VINCULADOS            337139
# 1  100 - ORDINARIOS NAO VINCULADOS            449092
# 2  100 - ORDINARIOS NAO VINCULADOS            339039
# 3  100 - ORDINARIOS NAO VINCULADOS            339092
# 4  100 - ORDINARIOS NAO VINCULADOS            339039
#
#                                Descricao_Elemento  Item_Despesa  \
# 0    OUTROS SERVIÇOS DE TERCEIROS PESSOA JURÍDICA      33713900
# 1               Despesas de Exercícios Anteriores      44909201
# 2  Outros Serviços de Terceiros - Pessoa Jurídica      33903912
# 3               Despesas de Exercícios Anteriores      33909211
# 4  Outros Serviços de Terceiros - Pessoa Jurídica      33903900
#
#                               Descricao_item_Despesa Orcamento_Atualizado  \
# 0     OUTROS SERVICOS DE TERCEIROS - PESSOA JURIDICA                 1000
# 1  Execução De Obras E Projetos De Ampliação  Rec...                    0
# 2          Bens Imóveis - Locação De Pessoa Jurídica                    0
# 3                             Bens Imóveis - Locação                    0
# 4     Outros Serviços De Terceiros - Pessoa Jurídica              4656404
#
#   Empenhado Liquidado Pago   Pago_Restos_Pagar
# 0         0         0    0                   0
# 1         0         0    0           436524 19
# 2         0         0    0  1540492 3500000001
# 3         0         0    0          5411685 96
# 4         0         0    0                   0

# %%
data.iloc[0]
# Out:
# Exercicio                                                           2016
# Orgao                                                                 11
# Unidade_Orcamentaria                                                   1
# Programa_de_Trabalho                                   11010412203032771
# Acao                                                                2771
# Descricao_Acao                 APOIO A AUTORIDADE PUBLICA OLIMPICA - APO
# Fonte_de_Recursos                                                    100
# Descricao_Fonte                          100 - ORDINARIOS NAO VINCULADOS
# Elemento_Despesa                                                  337139
# Descricao_Elemento          OUTROS SERVIÇOS DE TERCEIROS PESSOA JURÍDICA
# Item_Despesa                                                    33713900
# Descricao_item_Despesa    OUTROS SERVICOS DE TERCEIROS - PESSOA JURIDICA
# Orcamento_Atualizado                                                1000
# Empenhado                                                              0
# Liquidado                                                              0
# Pago                                                                   0
# Pago_Restos_Pagar                                                      0
# Name: 0, dtype: object

# %% [markdown]
# There is no way to identify which person/company provided the service for the city

# %% [markdown]
# ### Conclusion
# At first look there isn't much usable data. There's no CNPJ, nor reimbursements, or value spent.
#
# We could ask for: reimbursements images, CNPJ from the hired company, expense.
#
# Also we noted there were test data online which doesn't give much credit to the data that is on the site.
#
# We couldn't find information on expenses made on food, airplane tickets and hotels.
