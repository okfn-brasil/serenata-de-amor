# %% [markdown]
# # Building powerful image classification models using very little data
#
# This notebook was based in this link:
# https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html
#
# They have good explanation and good images to show how these networks compute image classification.
# So, before to continue go there, I only comented the strong changes to make this method works to your case.
#
# To use it, i'm suposing you already have instaled the requirements to convert pdf to images!
#
# ## Togheter with these previous requirements you have to install  Keras 2.0 API
#
# Wait.... Again more requirements...  What is Keras???
#
# ## Keras: Deep Learning library for TensorFlow and Theano
# https://github.com/fchollet/keras
#
# Yeap, let's include more functionalites in the serenata-de-amor :D
#
#
# # Main constraint of it
# 1) We need a training and validation set :/
#
# 2) But deep learning needs a lot of data... *Read the title ;)
#
# ## Solution >>> Let's build it.
#
# Here:: you can find my training and validation set
# https://drive.google.com/file/d/0B6F2XOmMAf28dDZoOWtmS050Skk/view?usp=sharing
#
# It is composed by 250 wrong reimbursiments, and 250 not wrong
#
# What i mean by wrong: http://www.camara.gov.br/cota-parlamentar/documentos/publ/2398/2015/5635048.pdf
#
# As you can see it don't has any description about the consumation
#
# And what is "NOT WRONG":
#
# http://www.camara.gov.br/cota-parlamentar//documentos/publ/1773/2014/5506259.pdf
#
#
# ## So Let's start to run our ML method (Remember to read the first link before to continue)

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
import os.path
import numpy as np

#fix random seed for reproducibility
seed = 2017
np.random.seed(seed)

train_data_dir = '../data/training set/ML/train'
validation_data_dir = '../data/training set/ML/validation'



nb_train_samples = sum([len(files) for r, d, files in os.walk(train_data_dir)])
nb_validation_samples = sum([len(files) for r, d, files in os.walk(validation_data_dir)])

print('no. of trained samples = ', nb_train_samples, ' no. of validation samples= ',nb_validation_samples)


#dimensions of our images.
img_width, img_height = 150, 150


epochs = 20 
batch_size = 3

if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)

model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

#this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=False)#As you can see i put it as FALSE and in the example link it is TRUE
#Explanation, there no possibility to write in a reverse way :P

#this is the augmentation configuration we will use for testing:
#only rescaling
test_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')

model.fit_generator(
    train_generator,
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)

model.save_weights('first_try.h5')
# Out:
# no. of trained samples =  721  no. of validation samples=  302
# Found 369 images belonging to 2 classes.
# Found 154 images belonging to 2 classes.
# Epoch 1/20
# 240/240 [==============================] - 116s - loss: 0.7055 - acc: 0.6000 - val_loss: 0.6392 - val_acc: 0.6745
# Epoch 2/20
# 240/240 [==============================] - 117s - loss: 0.5780 - acc: 0.7681 - val_loss: 1.2624 - val_acc: 0.6216
# Epoch 3/20
# 240/240 [==============================] - 123s - loss: 0.5652 - acc: 0.7681 - val_loss: 1.1324 - val_acc: 0.6655
# Epoch 4/20
# 240/240 [==============================] - 117s - loss: 0.5407 - acc: 0.8042 - val_loss: 0.8229 - val_acc: 0.7095
# Epoch 5/20
# 240/240 [==============================] - 123s - loss: 0.5220 - acc: 0.8000 - val_loss: 0.7422 - val_acc: 0.6858
# Epoch 6/20
# 240/240 [==============================] - 125s - loss: 0.4934 - acc: 0.8083 - val_loss: 0.8888 - val_acc: 0.6622
# Epoch 7/20
# 240/240 [==============================] - 131s - loss: 0.4867 - acc: 0.8208 - val_loss: 0.8087 - val_acc: 0.6622
# Epoch 8/20
# 240/240 [==============================] - 132s - loss: 0.4611 - acc: 0.8194 - val_loss: 1.2910 - val_acc: 0.6588
# Epoch 9/20
# 240/240 [==============================] - 176s - loss: 0.4345 - acc: 0.8333 - val_loss: 0.8169 - val_acc: 0.7061
# Epoch 10/20
# 240/240 [==============================] - 131s - loss: 0.4151 - acc: 0.8347 - val_loss: 0.7622 - val_acc: 0.6453
# Epoch 11/20
# 240/240 [==============================] - 125s - loss: 0.3662 - acc: 0.8486 - val_loss: 0.8768 - val_acc: 0.6318
# Epoch 12/20
# 240/240 [==============================] - 123s - loss: 0.4211 - acc: 0.8403 - val_loss: 0.6952 - val_acc: 0.6757
# Epoch 13/20
#  - ETA: 50s - loss: 0.3250 - acc: 0.7333
# Epoch 14/20
# 240/240 [==============================] - 126s - loss: 0.4690 - acc: 0.8542 - val_loss: 1.0364 - val_acc: 0.6723
# Epoch 15/20
# 240/240 [==============================] - 126s - loss: 0.3670 - acc: 0.8653 - val_loss: 1.1125 - val_acc: 0.7061
# Epoch 16/20
# 240/240 [==============================] - 130s - loss: 0.3626 - acc: 0.8514 - val_loss: 1.0244 - val_acc: 0.7061
# Epoch 17/20
# 240/240 [==============================] - 135s - loss: 0.3505 - acc: 0.8736 - val_loss: 0.6468 - val_acc: 0.6926
# Epoch 18/20
# 240/240 [==============================] - 155s - loss: 0.3285 - acc: 0.8819 - val_loss: 0.8623 - val_acc: 0.6946
# Epoch 19/20
# 240/240 [==============================] - 137s - loss: 0.3155 - acc: 0.8847 - val_loss: 0.9582 - val_acc: 0.6926
# Epoch 20/20
# 240/240 [==============================] - 134s - loss: 0.3460 - acc: 0.8847 - val_loss: 1.0510 - val_acc: 0.6824

# %% [markdown]
# # Result: A network with 70% of accuracy, Not bad to our small sample...
#
# # Let's use it on new reimbursements!
#
#
#
# ## I did a little script which create this workflow: csv -> download -> convert to png
# ## the cell bellow do it

# %%
# detect duplicate reimbursements
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import urllib
import glob
from __future__ import print_function
from wand.image import Image

def convert_pdf_png_and_save(file_name,new_file_name):
    """Convert a pdf file to png and save it at disk

    arguments:
    file_name -- the real path to access the pdf file on disk
    new_file_name -- my_path/12312.png
    """
    try:
        #Default arguments to read the file and has a good resolution
        with Image(filename=file_name, resolution=300) as img:
            img.compression_quality = 99
            print('width =', img.width)
            print('height =', img.height)
            print('pages = ', len(img.sequence))
            print('resolution = ', img.resolution)

            #Format choosed to convert the pdf to image
            with img.convert('png') as converted:
                converted.save(filename=new_file_name)
                return 1
    except Exception as ex:
        print(ex)
        return 0
            
def downloadDoc(url,pdf_directory):
    """Download a pdf file to a specified directory 
    Returns the name of the file, e.g., 123123.pdf

    arguments:
    url -- the pdf url to chamber of deputies web site, e.g., http://www.../documentos/publ/2437/2015/5645177.pdf
    pdf_directory -- the path to save the file on disk
    
    Exception -- returns None
    """
    #using the doc id as file name
    full_name= url.split("/")
    file_name = full_name[len(full_name)-1]
    try:
        print (url)
        print (file_name)
        #open the resquest and get the file
        with urllib.request.urlopen(url) as response, open(pdf_directory+file_name, 'wb') as out_file:
            data = response.read()
            #write the file on disk
            out_file.write(data)
            # return the name 
            return out_file.name 
    except Exception as ex:
        return None #case we get some exception we return None

"""convert the row of a dataframe to a string represinting the url for the files in the chamber of deputies
        Return a string to access the files in the chamber of deputies web site
    
        arguments:
        record -- row of a dataframe
"""
def document_url(record):
    return 'http://www.camara.gov.br/cota-parlamentar/documentos/publ/%s/%s/%s.pdf' %\
        (record['applicant_id'],record['year'], record['document_id'])

"""Download the files related to a dataframe and store them in an informed directory
        Returns the dataframe with the column filename filled
        arguments:
        sample -- the pandas dataframe
        pdf_directory -- base directory where we can access the file
"""  
def download_sample(sample,pdf_directory):
    for x in range(0,len(sample)):
        url = document_url(sample.iloc[x]) #get the url representation
        url = downloadDoc(url,pdf_directory) #download, store and get the file name
        if url != None :
            sample.iloc[x, sample.columns.get_loc('filename')]=url #fill the row with the filename

    
#Reading the reimbursements files
data = pd.read_csv('../data/2016-11-19-last-year.xz',
                   parse_dates=[16],
                   dtype={'document_id': np.str,
                          'congressperson_id': np.str,
                          'congressperson_document': np.str,
                          'term_id': np.str,
                          'cnpj_cpf': np.str,
                          'reimbursement_number': np.str})

#Directory where we will store the pdf downloaded OR where they already exist
pdf_directory="../data/pdfs/"

#I will look only the meals
data=data[data['subquota_description']=='Congressperson meal']

#creating a column to access the files latter
data['filename'] = ''
doc_ids=[]

#Get the pdfs files downloaded in our folder, e.g., /data
pdfs = glob.glob(pdf_directory+'*.pdf')

#Case we have pdf files we convert the pdf_files_name to doc_ids
for file in pdfs:
    full_name= file.split("/")
    file_name = full_name[len(full_name)-1]
    file_name= file_name.split(".pdf")
    file_name= file_name[0]
    doc_ids.append(file_name)
    
print ("recupered PDF files: {}".format(len(pdfs)))    

#Case we have pdf files we use them in our Machine learn method
if(len(pdfs)==0):
    data = data.sample(n=100)#Only 100 images to test (In my RUN i put 10000 YEAP, i will use them to refiny the training set)
    download_sample(data,pdf_directory)
else:
    data=data[data['document_id'].isin(doc_ids)]

#build a list of pdf_file_name to fill our dataframe directly
file_list = []
for x in range(0,len(data)):
    string = pdf_directory+"{}.pdf".format(data.iloc[x, data.columns.get_loc('document_id')])
    file_list.append(string)

data['filename']=file_list #fill it

file_png_list=[]
bad_index=[] #Bad requests to conversion which must be removed
for x in range(0,len(data)):
    if data.iloc[x]['filename']!="":
        #read the pdf file and convert to png
        newName=data.iloc[x, data.columns.get_loc('filename')]
        newName= newName.replace('.pdf','.png')
        converted = convert_pdf_png_and_save(data.iloc[x, data.columns.get_loc('filename')],newName)
        if(converted==1):
            file_png_list.append(newName)
        else:
            print("PNG failed removing index {}".format(x))
            bad_index.append(x)    

#remove bad requests            
data = data.drop(data.index[bad_index])
print("new dataframe len: {}".format(data.shape))

#Change the name of files
data['filename']=file_png_list
# Out:
# recupered PDF files: 0
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/137/2015/5790165.pdf
# 5790165.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/678/2015/5603837.pdf
# 5603837.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2429/2015/5749973.pdf
# 5749973.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2988/2015/5674918.pdf
# 5674918.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1001/2015/5622671.pdf
# 5622671.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2340/2015/5655777.pdf
# 5655777.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2920/2015/5677038.pdf
# 5677038.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1782/2015/5646833.pdf
# 5646833.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1005/2015/5832530.pdf
# 5832530.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2243/2015/5713033.pdf
# 5713033.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1892/2015/5603061.pdf
# 5603061.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2912/2015/5822111.pdf
# 5822111.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3077/2015/5862190.pdf
# 5862190.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3033/2015/5823029.pdf
# 5823029.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2937/2015/5695859.pdf
# 5695859.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3045/2015/5720229.pdf
# 5720229.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3076/2015/5609404.pdf
# 5609404.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3017/2015/5683220.pdf
# 5683220.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2989/2015/5780015.pdf
# 5780015.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/831/2015/5660120.pdf
# 5660120.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2379/2015/5655256.pdf
# 5655256.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1676/2015/5615007.pdf
# 5615007.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2906/2015/5838719.pdf
# 5838719.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1951/2015/5837281.pdf
# 5837281.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/198/2015/5758532.pdf
# 5758532.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2238/2015/5720915.pdf
# 5720915.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1458/2015/5878018.pdf
# 5878018.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2288/2015/5682882.pdf
# 5682882.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/184/2015/5890363.pdf
# 5890363.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3054/2015/5674296.pdf
# 5674296.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2950/2015/5816601.pdf
# 5816601.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2267/2015/5671222.pdf
# 5671222.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3033/2015/5849069.pdf
# 5849069.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1798/2015/5628929.pdf
# 5628929.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2934/2015/5737948.pdf
# 5737948.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1782/2015/5782562.pdf
# 5782562.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1901/2015/5609302.pdf
# 5609302.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2371/2015/5817683.pdf
# 5817683.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2944/2015/5669193.pdf
# 5669193.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1789/2015/5864632.pdf
# 5864632.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3033/2015/5712836.pdf
# 5712836.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1758/2015/5800226.pdf
# 5800226.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1860/2015/5661178.pdf
# 5661178.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1922/2015/5856968.pdf
# 5856968.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2928/2015/5779060.pdf
# 5779060.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/184/2015/5620904.pdf
# 5620904.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3038/2015/5644551.pdf
# 5644551.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2264/2015/5625888.pdf
# 5625888.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2299/2015/5667000.pdf
# 5667000.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3051/2015/5719771.pdf
# 5719771.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1699/2015/5884534.pdf
# 5884534.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2341/2015/5662494.pdf
# 5662494.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1935/2015/5878742.pdf
# 5878742.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1744/2015/5748948.pdf
# 5748948.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1924/2015/5725853.pdf
# 5725853.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2238/2015/5815026.pdf
# 5815026.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1175/2015/5823102.pdf
# 5823102.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2988/2015/5722147.pdf
# 5722147.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2974/2015/5847582.pdf
# 5847582.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3040/2015/5776127.pdf
# 5776127.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2933/2015/5826616.pdf
# 5826616.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2236/2015/5680527.pdf
# 5680527.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3010/2015/5688211.pdf
# 5688211.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1744/2015/5853774.pdf
# 5853774.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1514/2015/5758698.pdf
# 5758698.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2910/2015/5802181.pdf
# 5802181.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1873/2015/5901168.pdf
# 5901168.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2345/2015/5811805.pdf
# 5811805.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/527/2015/5656352.pdf
# 5656352.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1947/2015/5597945.pdf
# 5597945.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2907/2015/5880188.pdf
# 5880188.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/184/2015/5767104.pdf
# 5767104.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1175/2015/5676296.pdf
# 5676296.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/836/2015/5617598.pdf
# 5617598.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1922/2015/5640801.pdf
# 5640801.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3026/2015/5644192.pdf
# 5644192.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2366/2015/5633538.pdf
# 5633538.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3003/2015/5786058.pdf
# 5786058.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2937/2015/5791316.pdf
# 5791316.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2880/2015/5690835.pdf
# 5690835.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3070/2015/5874678.pdf
# 5874678.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3010/2015/5785543.pdf
# 5785543.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1737/2015/5807811.pdf
# 5807811.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2281/2015/5714377.pdf
# 5714377.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2995/2015/5738175.pdf
# 5738175.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2325/2015/5589857.pdf
# 5589857.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/705/2015/5729304.pdf
# 5729304.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2975/2015/5663235.pdf
# 5663235.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2379/2015/5701375.pdf
# 5701375.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3022/2015/5692444.pdf
# 5692444.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1693/2015/5596177.pdf
# 5596177.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1458/2015/5774410.pdf
# 5774410.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2927/2015/5802073.pdf
# 5802073.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/995/2015/5851565.pdf
# 5851565.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2887/2015/5714995.pdf
# 5714995.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1562/2015/5845054.pdf
# 5845054.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2256/2015/5778837.pdf
# 5778837.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2243/2015/5610335.pdf
# 5610335.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1958/2015/5639120.pdf
# 5639120.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2864/2015/5767545.pdf
# 5767545.pdf
# width = 2483
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 2550
# height = 3300
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2413
# height = 3404
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 2481
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2550
# height = 3300
# pages =  2
# resolution =  (300, 300)
# width = 2481
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 2483
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3513
# pages =  1
# resolution =  (300, 300)
# unable to open image `../data/pdfs/5890363.pdf': No such file or directory @ error/blob.c/OpenBlob/2712
# PNG failed removing index 28
# width = 2488
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2483
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 2413
# height = 3404
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2421
# height = 3413
# pages =  1
# resolution =  (300, 300)
# width = 2238
# height = 2658
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 1188
# height = 1200
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2550
# height = 3300
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2483
# height = 3517
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 2496
# height = 3529
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 2483
# height = 3517
# pages =  1
# resolution =  (300, 300)
# width = 2558
# height = 3313
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2496
# height = 3517
# pages =  2
# resolution =  (300, 300)
# unable to open image `../data/pdfs/5901168.pdf': No such file or directory @ error/blob.c/OpenBlob/2712
# PNG failed removing index 66
# width = 2488
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2413
# height = 3404
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 1775
# height = 1321
# pages =  1
# resolution =  (300, 300)
# width = 2550
# height = 3304
# pages =  1
# resolution =  (300, 300)
# width = 2550
# height = 3304
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2483
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 1088
# height = 1071
# pages =  1
# resolution =  (300, 300)
# width = 2481
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 975
# height = 1046
# pages =  1
# resolution =  (300, 300)
# width = 2558
# height = 3313
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2481
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2483
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2550
# height = 3300
# pages =  1
# resolution =  (300, 300)
# width = 2550
# height = 3300
# pages =  1
# resolution =  (300, 300)
# width = 2483
# height = 3517
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2496
# height = 3521
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3504
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 3300
# height = 2550
# pages =  1
# resolution =  (300, 300)
# new dataframe len: (98, 30)

# %% [markdown]
# # Here is where we play with our ML model
#
# 1) Use the before trained network
#
# 2) Get a new image and classify it as wrong or not
#
# 3) Keep only predictions with more 80% probability
#
# 4) Move it to another folder to future modifications

# %%
from keras.models import load_model
from keras.preprocessing.image import img_to_array, load_img
import shutil


#test_model = load_model('./first_try.h5')#I'm using the before model, if you want to load it from file use it
for png_file in file_png_list:
    try:
        img = load_img(png_file,False,target_size=(img_width,img_height))#read a iamge
        x = img_to_array(img)
        x = np.expand_dims(x, axis=0) #convert it
        preds = model.predict_classes(x) #predict it in our model :D
        prob = model.predict_proba(x)
        if(prob>=0.8):#Only keep the predictions with more than 80% of accuracy
            shutil.move(png_file, '../data/toCheck2')
            print(data[data['filename']==png_file])
    except Exception as ex:
# Out:
# [Errno 2] No such file or directory: '../data/pdfs/5790165.png'
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
#        document_id congressperson_name congressperson_id  \
# 290307     5713033         PEDRO UCZAI            160604
#
#        congressperson_document  term state party term_id  subquota_number  \
# 290307                     481  2015    SC    PT      55               13
#
#        subquota_description            ...             month  year  \
# 290307  Congressperson meal            ...                 6  2015
#
#        installment passenger leg_of_the_trip  batch_number  \
# 290307           0       NaN             NaN       1201998
#
#        reimbursement_number  reimbursement_value  applicant_id  \
# 290307                 5064                  NaN          2243
#
#                         filename
# 290307  ../data/pdfs/5713033.png
#
# [1 rows x 30 columns]
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# [Errno 2] No such file or directory: '../data/pdfs/5660120.png'
# [Errno 2] No such file or directory: '../data/pdfs/5655256.png'
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# [Errno 2] No such file or directory: '../data/pdfs/5849069.png'
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# [Errno 2] No such file or directory: '../data/pdfs/5719771.png'
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
#        document_id congressperson_name congressperson_id  \
# 329198     5878742       SÉRGIO MORAES            141542
#
#        congressperson_document  term state party term_id  subquota_number  \
# 329198                     512  2015    RS   PTB      55               13
#
#        subquota_description            ...             month  year  \
# 329198  Congressperson meal            ...                12  2015
#
#        installment passenger leg_of_the_trip  batch_number  \
# 329198           0       NaN             NaN       1252985
#
#        reimbursement_number  reimbursement_value  applicant_id  \
# 329198                 5275                  NaN          1935
#
#                         filename
# 329198  ../data/pdfs/5878742.png
#
# [1 rows x 30 columns]
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
#      document_id congressperson_name congressperson_id  \
# 2996     5748948       ADEMIR CAMILO            133374
#
#      congressperson_document  term state party term_id  subquota_number  \
# 2996                     520  2015    MG   PTN      55               13
#
#      subquota_description            ...             month  year installment  \
# 2996  Congressperson meal            ...                 7  2015           0
#
#      passenger leg_of_the_trip  batch_number reimbursement_number  \
# 2996       NaN             NaN       1213210                 5109
#
#       reimbursement_value  applicant_id                  filename
# 2996                  NaN          1744  ../data/pdfs/5748948.png
#
# [1 rows x 30 columns]
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# [Errno 2] No such file or directory: '../data/pdfs/5758698.png'
# [Errno 2] No such file or directory: '../data/pdfs/5802181.png'
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
#        document_id congressperson_name congressperson_id  \
# 348559     5656352      VALDIR COLATTO             74010
#
#        congressperson_document  term state party term_id  subquota_number  \
# 348559                     489  2015    SC  PMDB      55               13
#
#        subquota_description            ...             month  year  \
# 348559  Congressperson meal            ...                 4  2015
#
#        installment passenger leg_of_the_trip  batch_number  \
# 348559           0       NaN             NaN       1184158
#
#        reimbursement_number  reimbursement_value  applicant_id  \
# 348559                 5010                  NaN           527
#
#                         filename
# 348559  ../data/pdfs/5656352.png
#
# [1 rows x 30 columns]
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# [Errno 2] No such file or directory: '../data/pdfs/5786058.png'
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# [Errno 2] No such file or directory: '../data/pdfs/5738175.png'
# [Errno 2] No such file or directory: '../data/pdfs/5589857.png'
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# [Errno 2] No such file or directory: '../data/pdfs/5701375.png'
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# [Errno 2] No such file or directory: '../data/pdfs/5774410.png'
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
#       document_id congressperson_name congressperson_id  \
# 81930     5845054      DANIEL ALMEIDA             74060
#
#       congressperson_document  term state  party term_id  subquota_number  \
# 81930                     188  2015    BA  PCdoB      55               13
#
#       subquota_description            ...             month  year installment  \
# 81930  Congressperson meal            ...                11  2015           0
#
#       passenger leg_of_the_trip  batch_number reimbursement_number  \
# 81930       NaN             NaN       1242541                 5228
#
#        reimbursement_value  applicant_id                  filename
# 81930                  NaN          1562  ../data/pdfs/5845054.png
#
# [1 rows x 30 columns]
# [Errno 2] No such file or directory: '../data/pdfs/5778837.png'
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s

# %% [markdown]
# # Results:
#
# I got 2483 suspicious reimbursements. You can download them here:
# https://drive.google.com/file/d/0B6F2XOmMAf28eVBLUnRFQkZsSGs/view?usp=sharing
#
# I will validate them by hand and use it to argument the the top layers of my pre-trained network.
#
# # Conclusion
#
# Using this method we can find a lot of suspicious reimbursements :)
# Using this we created new pre-trained networks with few data :D
#
# It seems that our deputies are used to ask for reimbursements with poor description, #CHATIADO
#
# CEAP:
#
# O documento que comprova o pagamento não pode ter rasura, acréscimos, emendas ou entrelinhas, deve conter data e deve conter os serviços ou materiais descritos item por item, sem generalizações ou abreviaturas, podendo ser:

# %% [markdown]
# # PS: I would like to discuss some data in the train set
#
# In the folder: "not wrong", the recipe: 5496084.pdf
#
# It is clear to me that the description of the items was made by someone else than the restaurant, is it allowed ???
#
# Are the deputies or acessors changing a document?? What are the implications about it?
