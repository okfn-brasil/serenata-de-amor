# %% [markdown]
# # Building powerful image classification models using very little data
#
# This notebook was based in this link:
# https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html
#
# They have good explanation and good images to show how these networks compute image classification.
# So, before to continue go there!
# Ps: I only commented in my code the strong changes regarding they example.
#
# To use it i'm supposing you have installed the requirements to convert pdf to images.
# See this notebook: 2017-05-05-silvio-PDF-to-PNG-SIFT-descriptors.ipynb
#
# ## Togheter with these previous requirements you have to install  Keras 2.0 API
#
# What is Keras???
#
# ## Keras: Deep Learning library for TensorFlow and Theano
# https://github.com/fchollet/keras
#
# Yeap, let's include more functionalities in the serenata-de-amor :D
#
#
# # Main constraint of it: We need a training and validation set :/
#
# ## Solution >>> Let's build it.
#
# ## New Dataset
# Here: https://drive.google.com/file/d/0B6F2XOmMAf28U1FsMTN0QXNPX28/view?usp=sharing
# It includes, images, model and csv .
#
#
# Here: you can find my first training and validation set
# https://drive.google.com/file/d/0B6F2XOmMAf28dDZoOWtmS050Skk/view?usp=sharing
#
# #### It is composed by 250 wrong reimbursements, and 250 not wrong
#
# What i mean by wrong: http://www.camara.gov.br/cota-parlamentar/documentos/publ/2398/2015/5635048.pdf
#
# As you can see it don't has any description about the consummation
#
# And what is "NOT WRONG":
#
# http://www.camara.gov.br/cota-parlamentar//documentos/publ/1773/2014/5506259.pdf
#
# This first dataset was not big, but it allowed us to do the first steps and improve the machine learn model
#
# PS: using only this data i built a model with 70% accuracy
# Take a look at this pull: https://github.com/datasciencebr/serenata-de-amor/pull/238
#
# Moving on, i executed it over 10000 and i got 2483 reimbursements regarding the two classes (Wrong, not wrong).
#
# You can download them here:
# https://drive.google.com/file/d/0B6F2XOmMAf28eVBLUnRFQkZsSGs/view?usp=sharing
#
# # All these reimbursements were validate by hand
# # Thanks so much everyone involved on it :D
#
# Take a look at this great collaborative work: https://docs.google.com/spreadsheets/d/1o7P79iMw2VnJypSZNHrsDjud398g4vXpZdrGMMqe6qA/edit?usp=sharing
#
# Here: you can find the up-to-date reimbursements
# https://drive.google.com/file/d/0B6F2XOmMAf28U1FsMTN0QXNPX28/view?usp=sharing
# #### It is composed by 1691 wrong reimbursements, and 1691 not wrong (*Now they are called, positive, negative)
#
#
# ## PS: The first training set was also reevaluated after discussion with @anaschwendler
# ### In the spreadsheet they are in orange color.
#
#
# ## So Let's start to run our DeepLearning method (Remember to read the first link before to continue)

# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras import backend as K
from keras.callbacks import ModelCheckpoint
import os.path
import numpy as np

#fix random seed for reproducibility
seed = 2017
np.random.seed(seed)

train_data_dir = '../data/DeepLearningKeras/dataset/training/'
validation_data_dir = '../data/DeepLearningKeras/dataset/validation/'



nb_train_samples = sum([len(files) for r, d, files in os.walk(train_data_dir)])
nb_validation_samples = sum([len(files) for r, d, files in os.walk(validation_data_dir)])

print('no. of trained samples = ', nb_train_samples, ' no. of validation samples= ',nb_validation_samples)


#dimensions of our images.
img_width, img_height = 300, 300


epochs = 20 
batch_size = 15

if K.image_data_format() == 'channels_first':
    input_shape = (3, img_width, img_height)
else:
    input_shape = (img_width, img_height, 3)

model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=input_shape))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
              optimizer='rmsprop',
              metrics=['accuracy'])

#this is the augmentation configuration we will use for training
train_datagen = ImageDataGenerator(
    rescale=1. / 255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=False)#As you can see i put it as FALSE and on link example it is TRUE
#Explanation, there no possibility to write in a reverse way :P

#this is the augmentation configuration we will use for testing:
#only rescaling
test_datagen = ImageDataGenerator(rescale=1. / 255)

train_generator = train_datagen.flow_from_directory(
    train_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')

validation_generator = test_datagen.flow_from_directory(
    validation_data_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary')

#It allow us to save only the best model between the iterations 
checkpointer = ModelCheckpoint(filepath="weights.hdf5", verbose=1, save_best_only=True)

model.fit_generator(
    train_generator,
     callbacks=[checkpointer], #And we set the parameter to save only the best model
    steps_per_epoch=nb_train_samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=nb_validation_samples // batch_size)
# Out:
# no. of trained samples =  2366  no. of validation samples=  500
# Found 2366 images belonging to 2 classes.
# Found 500 images belonging to 2 classes.
# Epoch 1/20
# Epoch 00000: val_loss improved from inf to 0.48977, saving model to weights.hdf5
# 157/157 [==============================] - 1070s - loss: 0.8365 - acc: 0.6038 - val_loss: 0.4898 - val_acc: 0.8343
# Epoch 2/20
# Epoch 00001: val_loss improved from 0.48977 to 0.43071, saving model to weights.hdf5
# 157/157 [==============================] - 1057s - loss: 0.6211 - acc: 0.6998 - val_loss: 0.4307 - val_acc: 0.8384
# Epoch 3/20
# Epoch 00002: val_loss improved from 0.43071 to 0.30383, saving model to weights.hdf5
# 157/157 [==============================] - 976s - loss: 0.5445 - acc: 0.7595 - val_loss: 0.3038 - val_acc: 0.9134
# Epoch 4/20
# Epoch 00003: val_loss did not improve
# 157/157 [==============================] - 757s - loss: 0.4661 - acc: 0.8186 - val_loss: 0.3359 - val_acc: 0.9052
# Epoch 5/20
# Epoch 00004: val_loss improved from 0.30383 to 0.28274, saving model to weights.hdf5
# 157/157 [==============================] - 815s - loss: 0.4446 - acc: 0.8246 - val_loss: 0.2827 - val_acc: 0.8990
# Epoch 6/20
# Epoch 00005: val_loss did not improve
# 157/157 [==============================] - 638s - loss: 0.4082 - acc: 0.8363 - val_loss: 0.3158 - val_acc: 0.8907
# Epoch 7/20
# Epoch 00006: val_loss did not improve
# 157/157 [==============================] - 640s - loss: 0.4161 - acc: 0.8366 - val_loss: 0.2972 - val_acc: 0.8969
# Epoch 8/20
# Epoch 00007: val_loss improved from 0.28274 to 0.23683, saving model to weights.hdf5
# 157/157 [==============================] - 642s - loss: 0.4015 - acc: 0.8572 - val_loss: 0.2368 - val_acc: 0.9381
# Epoch 9/20
# Epoch 00008: val_loss did not improve
# 157/157 [==============================] - 635s - loss: 0.4052 - acc: 0.8500 - val_loss: 0.2722 - val_acc: 0.9340
# Epoch 10/20
# Epoch 00009: val_loss improved from 0.23683 to 0.23616, saving model to weights.hdf5
# 157/157 [==============================] - 654s - loss: 0.3734 - acc: 0.8614 - val_loss: 0.2362 - val_acc: 0.9258
# Epoch 11/20
# Epoch 00010: val_loss did not improve
# 157/157 [==============================] - 644s - loss: 0.4014 - acc: 0.8618 - val_loss: 0.2628 - val_acc: 0.9320
# Epoch 12/20
# Epoch 00011: val_loss did not improve
# 157/157 [==============================] - 634s - loss: 0.3816 - acc: 0.8606 - val_loss: 0.2522 - val_acc: 0.9237
# Epoch 13/20
# Epoch 00012: val_loss did not improve
# 157/157 [==============================] - 635s - loss: 0.3741 - acc: 0.8623 - val_loss: 0.2720 - val_acc: 0.9216
# Epoch 14/20
# Epoch 00013: val_loss improved from 0.23616 to 0.22647, saving model to weights.hdf5
# 157/157 [==============================] - 607s - loss: 0.3715 - acc: 0.8691 - val_loss: 0.2265 - val_acc: 0.9423
# Epoch 15/20
# Epoch 00014: val_loss improved from 0.22647 to 0.19187, saving model to weights.hdf5
# 157/157 [==============================] - 605s - loss: 0.3718 - acc: 0.8637 - val_loss: 0.1919 - val_acc: 0.9423
# Epoch 16/20
# Epoch 00015: val_loss did not improve
# 157/157 [==============================] - 607s - loss: 0.3435 - acc: 0.8727 - val_loss: 0.2086 - val_acc: 0.9381
# Epoch 17/20
# Epoch 00016: val_loss did not improve
# 157/157 [==============================] - 622s - loss: 0.3617 - acc: 0.8733 - val_loss: 0.3123 - val_acc: 0.8948
# Epoch 18/20
# Epoch 00017: val_loss did not improve
# 157/157 [==============================] - 589s - loss: 0.3967 - acc: 0.8608 - val_loss: 0.2727 - val_acc: 0.9052
# Epoch 19/20
# Epoch 00018: val_loss did not improve
# 157/157 [==============================] - 633s - loss: 0.3639 - acc: 0.8702 - val_loss: 0.2549 - val_acc: 0.9278
# Epoch 20/20
# Epoch 00019: val_loss did not improve
# 157/157 [==============================] - 601s - loss: 0.3653 - acc: 0.8693 - val_loss: 0.2413 - val_acc: 0.9320

# %% [markdown]
# # Result: A network with 94% of accuracy!!! Big improvement regarding the first we buit...
#
# 156/157 [============================>.] - ETA: 3s - loss: 0.3726 - acc: 0.8682 Epoch 00013: val_loss improved from 0.23616 to 0.22647, saving model to weights.hdf5
# 157/157 [==============================] - 607s - loss: 0.3715 - acc: 0.8691 - val_loss: 0.2265 - val_acc: 0.9423
#
# # Let's use it on an external set of reimbursements!
# ### @vmesel recommended it, thanks for the feedback :D

# %%
from keras.models import load_model
from keras.preprocessing.image import img_to_array, load_img
import glob
import numpy as np
import pandas as pd

def goldStandard(png_directory,value):
    png = glob.glob(png_directory+'*.png')
    data = list()
    for f in png:
        data.append(f)
    df = pd.DataFrame(data,columns=['Image'])
    df['Reference']=value
   
    return df

png_directory='../data/DeepLearningKeras/dataset/pos_validation/positive/'
df1 = goldStandard(png_directory,1)
png_directory='../data/DeepLearningKeras/dataset/pos_validation/negative/'
df2= goldStandard(png_directory,0)
frames = [df1, df2]
df = pd.concat(frames)
print(df.head())
print(df.tail())
test_model = load_model('./weights.hdf5')#I'm using the saved file to load the model

#dimensions of our images.
img_width, img_height = 300, 300
predicted=list()
for obj in df.iterrows():
    try:
        print(obj[1].Image)
        img = load_img(obj[1].Image,False,target_size=(img_width,img_height))#read a image
        x = img_to_array(img)
        x = np.expand_dims(x, axis=0) #convert it
        preds = test_model.predict_classes(x) #predict it in our model :D
        prob = test_model.predict_proba(x) #get the probability of prediciton
        if(prob>=0.8 and preds==1):#Only keep the predictions with more than 80% of accuracy and the class 1 (suspicious)
            print("suspicious!!! prob:",prob)
            predicted.append(1)
        else:
            predicted.append(0)
    except Exception as ex:
            print(ex)
df['Predicted']=predicted
# Out:
#                                                Image  Reference
png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# suspicious!!! prob: [[ 1.]]
# ../data/DeepLearningKeras/dataset/pos_validation/positive/5831117.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# suspicious!!! prob: [[ 1.]]
# ../data/DeepLearningKeras/dataset/pos_validation/positive/5861928.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# suspicious!!! prob: [[ 1.]]
# ../data/DeepLearningKeras/dataset/pos_validation/positive/5853231.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# suspicious!!! prob: [[ 1.]]
# ../data/DeepLearningKeras/dataset/pos_validation/positive/5826089.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# suspicious!!! prob: [[ 1.]]
# ../data/DeepLearningKeras/dataset/pos_validation/positive/5849064.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# suspicious!!! prob: [[ 1.]]
# ../data/DeepLearningKeras/dataset/pos_validation/positive/5853467.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# suspicious!!! prob: [[ 1.]]
# ../data/DeepLearningKeras/dataset/pos_validation/positive/5868340.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# suspicious!!! prob: [[ 1.]]
# ../data/DeepLearningKeras/dataset/pos_validation/positive/5824678.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# suspicious!!! prob: [[ 1.]]
# ../data/DeepLearningKeras/dataset/pos_validation/positive/5868348.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# suspicious!!! prob: [[ 1.]]
# ../data/DeepLearningKeras/dataset/pos_validation/positive/5871348.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/positive/5873499.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# suspicious!!! prob: [[ 1.]]
# ../data/DeepLearningKeras/dataset/pos_validation/positive/5874617.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# suspicious!!! prob: [[ 1.]]
# ../data/DeepLearningKeras/dataset/pos_validation/positive/5848099.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# suspicious!!! prob: [[ 1.]]
# ../data/DeepLearningKeras/dataset/pos_validation/positive/5830848.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# suspicious!!! prob: [[ 1.]]
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5836315.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5856593.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5865898.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5840703.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5879985.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5861153.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5843958.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5829700.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5850331.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5853215.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5875864.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5836546.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5877788.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5845336.png
# ...
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5869847.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5872542.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5882361.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5881402.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# suspicious!!! prob: [[ 1.]]
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5834878.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5858783.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5845519.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5865331.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5834406.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# suspicious!!! prob: [[ 1.]]
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5830093.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5863488.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5835353.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5851125.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5834364.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5840979.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5833552.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5831947.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5835697.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5855464.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5835847.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5856680.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5835556.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5868451.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5884197.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5859512.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5844340.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5874188.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5864724.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5849852.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5830815.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5843768.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5878815.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5850038.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5877462.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5834236.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5850641.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5855139.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5843863.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5848181.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5877440.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5847766.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5884368.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5879811.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5886665.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5853730.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5885401.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5851134.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5836540.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5849659.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5885039.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# suspicious!!! prob: [[ 1.]]
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5849585.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5845981.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5863109.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5857645.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5862388.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5857965.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5871299.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5858026.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5839275.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5842687.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5833900.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5860287.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5841215.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# suspicious!!! prob: [[ 1.]]
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5832680.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5860137.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5863728.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5878487.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5845512.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# suspicious!!! prob: [[ 1.]]
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5862728.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5862479.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5831713.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5862869.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5869557.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# suspicious!!! prob: [[ 1.]]
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5885747.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5876653.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5842933.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5876401.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5841014.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5854984.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5850067.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5885437.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5865640.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# suspicious!!! prob: [[ 1.]]
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5846351.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5865731.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# suspicious!!! prob: [[ 1.]]
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5857331.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5852912.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5835178.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5873152.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5832265.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5833119.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5841715.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5850467.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5855596.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# suspicious!!! prob: [[ 1.]]
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5833750.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5877631.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5867844.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5869528.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5880599.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5856115.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5851927.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5880272.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# ../data/DeepLearningKeras/dataset/pos_validation/negative/5850617.png
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s

# %% [markdown]
# # After to run the Model over the pos_validation set
# ## Let's verify how is the performance!

# %%
from sklearn import metrics
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from sklearn.metrics import roc_curve, auc

fpr, tpr, _= metrics.roc_curve(df.Reference,df.Predicted)
roc_auc = auc(fpr, tpr)
print("Confusion matrix")
print(metrics.confusion_matrix(df.Reference,df.Predicted))
print(" accuracy ",metrics.accuracy_score(df.Reference,df.Predicted))
print(" AUC ",roc_auc)
print(" precision ",metrics.precision_score(df.Reference,df.Predicted))
print(" recall ",metrics.recall_score(df.Reference,df.Predicted))
print(" f1-score ",metrics.f1_score(df.Reference,df.Predicted))
# Out:
# Confusion matrix
# [[228  22]
#  [ 13 237]]
#  accuracy  0.93
#  AUC  0.93
#  precision  0.915057915058
#  recall  0.948
#  f1-score  0.931237721022

# %% [markdown]
# # These results are amazing!! All metrics are above 91% !!
#
# # Conclusion:
# ## We have a new classifier which detects generalization in the reimbursements
#
# ## It handle with CEAP: Article 4, paragraph 3 (***Generalizations )
# The receipt or invoice must not have erasures, additions or amendments, must be dated and must list without generalizations or abbreviations each of the services or products purchased; it can be:
#
# CEAP:
# 3. O documento que comprova o pagamento não pode ter rasura, acréscimos, emendas ou entrelinhas, deve conter data e deve conter os serviços ou materiais descritos item por item, sem generalizações ou abreviaturas, podendo ser:
#
#
# # How to use it?
#
# ### Download the new Dataset, take the weights.hdf5 file and then use the code from cell [46]

# %% [markdown]
# # The cells bellow belongs to the first ML model
# ## Basically it creates the workflow: csv -> download pdf -> convert to png -> predict png in the ML model
#
# ## I kept it for those which would like to do something similar. Moreover it contains the first discussion we had about the model and some suspicious reimbursements

# %%
# detect duplicate reimbursements
import os
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import cv2
import urllib
import glob
from __future__ import print_function
from wand.image import Image

def convert_pdf_png_and_save(file_name,new_file_name):
    """Convert a pdf file to png and save it at disk

    arguments:
    file_name -- the real path to access the pdf file on disk
    new_file_name -- my_path/12312.png
    """
    try:
        #Default arguments to read the file and has a good resolution
        with Image(filename=file_name, resolution=300) as img:
            img.compression_quality = 99
            print('width =', img.width)
            print('height =', img.height)
            print('pages = ', len(img.sequence))
            print('resolution = ', img.resolution)

            #Format choosed to convert the pdf to image
            with img.convert('png') as converted:
                converted.save(filename=new_file_name)
                return 1
    except Exception as ex:
        print(ex)
        return 0
            
def downloadDoc(url,pdf_directory):
    """Download a pdf file to a specified directory 
    Returns the name of the file, e.g., 123123.pdf

    arguments:
    url -- the pdf url to chamber of deputies web site, e.g., http://www.../documentos/publ/2437/2015/5645177.pdf
    pdf_directory -- the path to save the file on disk
    
    Exception -- returns None
    """
    #using the doc id as file name
    full_name= url.split("/")
    file_name = full_name[len(full_name)-1]
    try:
        print (url)
        print (file_name)
        #open the resquest and get the file
        with urllib.request.urlopen(url) as response, open(pdf_directory+file_name, 'wb') as out_file:
            data = response.read()
            #write the file on disk
            out_file.write(data)
            # return the name 
            return out_file.name 
    except Exception as ex:
        return None #case we get some exception we return None

"""convert the row of a dataframe to a string represinting the url for the files in the chamber of deputies
        Return a string to access the files in the chamber of deputies web site
    
        arguments:
        record -- row of a dataframe
"""
def document_url(record):
    return 'http://www.camara.gov.br/cota-parlamentar/documentos/publ/%s/%s/%s.pdf' %\
        (record['applicant_id'],record['year'], record['document_id'])

"""Download the files related to a dataframe and store them in an informed directory
        Returns the dataframe with the column filename filled
        arguments:
        sample -- the pandas dataframe
        pdf_directory -- base directory where we can access the file
"""  
def download_sample(sample,pdf_directory):
    for x in range(0,len(sample)):
        url = document_url(sample.iloc[x]) #get the url representation
        url = downloadDoc(url,pdf_directory) #download, store and get the file name
        if url != None :
            sample.iloc[x, sample.columns.get_loc('filename')]=url #fill the row with the filename

    
#Reading the reimbursements files
data = pd.read_csv('../data/2016-11-19-last-year.xz',
                   parse_dates=[16],
                   dtype={'document_id': np.str,
                          'congressperson_id': np.str,
                          'congressperson_document': np.str,
                          'term_id': np.str,
                          'cnpj_cpf': np.str,
                          'reimbursement_number': np.str})

#Directory where we will store the pdf downloaded OR where they already exist
pdf_directory="../data/pdfs/"

#I will look only the meals
data=data[data['subquota_description']=='Congressperson meal']

#creating a column to access the files latter
data['filename'] = ''


# Reference for our model.
link = 'https://drive.google.com/uc?export=download&id=0B6F2XOmMAf28dHM5M0tmSy1JZzA'

response = urllib.request.urlopen(link)

csv_ref = pd.DataFrame.from_csv(response)

for index, refs in csv_ref:
    full_name= refs['tocheck'].split("/")
    file_name = full_name[len(full_name)-1]
    doc_ids.append(file_name)
    
print ("recupered Referemces: {}".format(len(doc_ids)))    

data=data[data['document_id'].isin(doc_ids)]

#build a list of pdf_file_name to fill our dataframe directly
file_list = []
for x in range(0,len(data)):
    string = pdf_directory+"{}.pdf".format(data.iloc[x, data.columns.get_loc('document_id')])
    file_list.append(string)

data['filename']=file_list #fill it

file_png_list=[]
bad_index=[] #Bad requests to conversion which must be removed
for x in range(0,len(data)):
    if data.iloc[x]['filename']!="":
        #read the pdf file and convert to png
        newName=data.iloc[x, data.columns.get_loc('filename')]
        newName= newName.replace('.pdf','.png')
        converted = convert_pdf_png_and_save(data.iloc[x, data.columns.get_loc('filename')],newName)
        if(converted==1):
            file_png_list.append(newName)
        else:
            print("PNG failed removing index {}".format(x))
            bad_index.append(x)    

#remove bad requests            
data = data.drop(data.index[bad_index])
print("new dataframe len: {}".format(data.shape))

#Change the name of files
data['filename']=file_png_list
# Out:
# recupered PDF files: 0
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/137/2015/5790165.pdf
# 5790165.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/678/2015/5603837.pdf
# 5603837.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2429/2015/5749973.pdf
# 5749973.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2988/2015/5674918.pdf
# 5674918.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1001/2015/5622671.pdf
# 5622671.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2340/2015/5655777.pdf
# 5655777.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2920/2015/5677038.pdf
# 5677038.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1782/2015/5646833.pdf
# 5646833.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1005/2015/5832530.pdf
# 5832530.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2243/2015/5713033.pdf
# 5713033.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1892/2015/5603061.pdf
# 5603061.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2912/2015/5822111.pdf
# 5822111.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3077/2015/5862190.pdf
# 5862190.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3033/2015/5823029.pdf
# 5823029.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2937/2015/5695859.pdf
# 5695859.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3045/2015/5720229.pdf
# 5720229.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3076/2015/5609404.pdf
# 5609404.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3017/2015/5683220.pdf
# 5683220.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2989/2015/5780015.pdf
# 5780015.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/831/2015/5660120.pdf
# 5660120.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2379/2015/5655256.pdf
# 5655256.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1676/2015/5615007.pdf
# 5615007.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2906/2015/5838719.pdf
# 5838719.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1951/2015/5837281.pdf
# 5837281.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/198/2015/5758532.pdf
# 5758532.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2238/2015/5720915.pdf
# 5720915.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1458/2015/5878018.pdf
# 5878018.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2288/2015/5682882.pdf
# 5682882.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/184/2015/5890363.pdf
# 5890363.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3054/2015/5674296.pdf
# 5674296.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2950/2015/5816601.pdf
# 5816601.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2267/2015/5671222.pdf
# 5671222.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3033/2015/5849069.pdf
# 5849069.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1798/2015/5628929.pdf
# 5628929.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2934/2015/5737948.pdf
# 5737948.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1782/2015/5782562.pdf
# 5782562.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1901/2015/5609302.pdf
# 5609302.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2371/2015/5817683.pdf
# 5817683.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2944/2015/5669193.pdf
# 5669193.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1789/2015/5864632.pdf
# 5864632.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3033/2015/5712836.pdf
# 5712836.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1758/2015/5800226.pdf
# 5800226.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1860/2015/5661178.pdf
# 5661178.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/1922/2015/5856968.pdf
# 5856968.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2928/2015/5779060.pdf
# 5779060.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/184/2015/5620904.pdf
# 5620904.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/3038/2015/5644551.pdf
# 5644551.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/2264/2015/5625888.pdf
# 5625888.pdf
# http://www.camara.gov.br/cota-parlamentar/documentos/publ/
# width = 2488
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2413
# height = 3404
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 1775
# height = 1321
# pages =  1
# resolution =  (300, 300)
# width = 2550
# height = 3304
# pages =  1
# resolution =  (300, 300)
# width = 2550
# height = 3304
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2483
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 1088
# height = 1071
# pages =  1
# resolution =  (300, 300)
# width = 2481
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 975
# height = 1046
# pages =  1
# resolution =  (300, 300)
# width = 2558
# height = 3313
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3513
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2481
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2483
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2550
# height = 3300
# pages =  1
# resolution =  (300, 300)
# width = 2550
# height = 3300
# pages =  1
# resolution =  (300, 300)
# width = 2483
# height = 3517
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2496
# height = 3521
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3504
# pages =  1
# resolution =  (300, 300)
# width = 2479
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 2488
# height = 3508
# pages =  1
# resolution =  (300, 300)
# width = 3300
# height = 2550
# pages =  1
# resolution =  (300, 300)
# new dataframe len: (98, 30)

# %% [markdown]
# # Here is where we play with our ML model
#
# 1) Use the before trained network
#
# 2) Get a new image and classify it as wrong or not
#
# 3) Keep only predictions with more 80% probability
#
# 4) Move it to another folder to future modifications

# %%
from keras.models import load_model
from keras.preprocessing.image import img_to_array, load_img
import shutil


#test_model = load_model('./first_try.h5')#I'm using the before model, if you want to load it from file use it
for png_file in file_png_list:
    try:
        img = load_img(png_file,False,target_size=(img_width,img_height))#read a iamge
        x = img_to_array(img)
        x = np.expand_dims(x, axis=0) #convert it
        preds = model.predict_classes(x) #predict it in our model :D
        prob = model.predict_proba(x)
        if(prob>=0.8):#Only keep the predictions with more than 80% of accuracy
            shutil.move(png_file, '../data/toCheck2')
            print(data[data['filename']==png_file])
    except Exception as ex:
# Out:
# [Errno 2] No such file or directory: '../data/pdfs/5790165.png'
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
#        document_id congressperson_name congressperson_id  \
# 290307     5713033         PEDRO UCZAI            160604
#
#        congressperson_document  term state party term_id  subquota_number  \
# 290307                     481  2015    SC    PT      55               13
#
#        subquota_description            ...             month  year  \
# 290307  Congressperson meal            ...                 6  2015
#
#        installment passenger leg_of_the_trip  batch_number  \
# 290307           0       NaN             NaN       1201998
#
#        reimbursement_number  reimbursement_value  applicant_id  \
# 290307                 5064                  NaN          2243
#
#                         filename
# 290307  ../data/pdfs/5713033.png
#
# [1 rows x 30 columns]
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# [Errno 2] No such file or directory: '../data/pdfs/5660120.png'
# [Errno 2] No such file or directory: '../data/pdfs/5655256.png'
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# [Errno 2] No such file or directory: '../data/pdfs/5849069.png'
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# [Errno 2] No such file or directory: '../data/pdfs/5719771.png'
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
#        document_id congressperson_name congressperson_id  \
# 329198     5878742       SÉRGIO MORAES            141542
#
#        congressperson_document  term state party term_id  subquota_number  \
# 329198                     512  2015    RS   PTB      55               13
#
#        subquota_description            ...             month  year  \
# 329198  Congressperson meal            ...                12  2015
#
#        installment passenger leg_of_the_trip  batch_number  \
# 329198           0       NaN             NaN       1252985
#
#        reimbursement_number  reimbursement_value  applicant_id  \
# 329198                 5275                  NaN          1935
#
#                         filename
# 329198  ../data/pdfs/5878742.png
#
# [1 rows x 30 columns]
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
#      document_id congressperson_name congressperson_id  \
# 2996     5748948       ADEMIR CAMILO            133374
#
#      congressperson_document  term state party term_id  subquota_number  \
# 2996                     520  2015    MG   PTN      55               13
#
#      subquota_description            ...             month  year installment  \
# 2996  Congressperson meal            ...                 7  2015           0
#
#      passenger leg_of_the_trip  batch_number reimbursement_number  \
# 2996       NaN             NaN       1213210                 5109
#
#       reimbursement_value  applicant_id                  filename
# 2996                  NaN          1744  ../data/pdfs/5748948.png
#
# [1 rows x 30 columns]
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# [Errno 2] No such file or directory: '../data/pdfs/5758698.png'
# [Errno 2] No such file or directory: '../data/pdfs/5802181.png'
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
#        document_id congressperson_name congressperson_id  \
# 348559     5656352      VALDIR COLATTO             74010
#
#        congressperson_document  term state party term_id  subquota_number  \
# 348559                     489  2015    SC  PMDB      55               13
#
#        subquota_description            ...             month  year  \
# 348559  Congressperson meal            ...                 4  2015
#
#        installment passenger leg_of_the_trip  batch_number  \
# 348559           0       NaN             NaN       1184158
#
#        reimbursement_number  reimbursement_value  applicant_id  \
# 348559                 5010                  NaN           527
#
#                         filename
# 348559  ../data/pdfs/5656352.png
#
# [1 rows x 30 columns]
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# [Errno 2] No such file or directory: '../data/pdfs/5786058.png'
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# [Errno 2] No such file or directory: '../data/pdfs/5738175.png'
# [Errno 2] No such file or directory: '../data/pdfs/5589857.png'
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# [Errno 2] No such file or directory: '../data/pdfs/5701375.png'
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# [Errno 2] No such file or directory: '../data/pdfs/5774410.png'
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
#       document_id congressperson_name congressperson_id  \
# 81930     5845054      DANIEL ALMEIDA             74060
#
#       congressperson_document  term state  party term_id  subquota_number  \
# 81930                     188  2015    BA  PCdoB      55               13
#
#       subquota_description            ...             month  year installment  \
# 81930  Congressperson meal            ...                11  2015           0
#
#       passenger leg_of_the_trip  batch_number reimbursement_number  \
# 81930       NaN             NaN       1242541                 5228
#
#        reimbursement_value  applicant_id                  filename
# 81930                  NaN          1562  ../data/pdfs/5845054.png
#
# [1 rows x 30 columns]
# [Errno 2] No such file or directory: '../data/pdfs/5778837.png'
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s
# 1/1 [==============================] - 0s

# %% [markdown]
# # Results:
#
# I got 2483 suspicious reimbursements. You can download them here:
# https://drive.google.com/file/d/0B6F2XOmMAf28eVBLUnRFQkZsSGs/view?usp=sharing
#
# I will validate them by hand and use it to argument the the top layers of my pre-trained network.
#
# # Conclusion
#
# Using this method we can find a lot of suspicious reimbursements :)
# Using this we created new pre-trained networks with few data :D
#
# It seems that our deputies are used to ask for reimbursements with poor description, #CHATEADO
#
# CEAP:
#
# O documento que comprova o pagamento não pode ter rasura, acréscimos, emendas ou entrelinhas, deve conter data e deve conter os serviços ou materiais descritos item por item, sem generalizações ou abreviaturas, podendo ser:

# %% [markdown]
# # PS: I would like to discuss some data in the train set
#
# In the folder: "not wrong", the recipe: 5496084.pdf
#
# It is clear to me that the description of the items was made by someone else than the restaurant, is it allowed ???
#
# Are the deputies or assessors changing a document?? What are the implications about it?
