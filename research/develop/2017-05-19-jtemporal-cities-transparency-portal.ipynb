# %% [markdown]
# # First Study on Brazilian Cities Transparency Portal
# In this dataset we have a population projection for each Brazilian city in the year of 2013.

# %%
import pandas as pd
import numpy as np

# We first collected the data with population estimatives, 
# we can use it later to do some comparisions or to use it later
cities = pd.read_excel('../data/Cidades - estimativa 2013.xlsx',
                       converters={'COD. UF': np.str, 'COD. MUNIC': np.str},
                       sheetname=None, header=0)

# %%
data = pd.DataFrame()
for key in cities.keys():
    data = pd.concat([data, cities[key]])
    
data = data.reset_index(drop=True)
data.shape
# Out:
# (5584, 5)

# %% [markdown]
# We should see 5570 rows because that's the number of cities that IBGE says that Brazil have. The different amount of rows leads me to believe there are metadata from the `.xlsx` messing with our data

# %% [markdown]
# ## Translating column names

# %%
data.rename(columns={
        'UF': 'state',
        'COD. UF': 'state_id',
        'COD. MUNIC': 'city_id',
        'NOME DO MUNICÍPIO': 'city_name',
        'POPULAÇÃO ESTIMADA': 'population_projection'
    }, inplace=True)
data.head()
# Out:
#   state state_id city_id                city_name population_projection
# 0    RO       11      15    Alta Floresta D'Oeste                 25728
# 1    RO       11     379  Alto Alegre dos Parecis                 13827
# 2    RO       11     403             Alto Paraíso                 19459
# 3    RO       11     346         Alvorada D'Oeste                 17399
# 4    RO       11      23                Ariquemes                101269

# %% [markdown]
# ## Formating `city_id`
#
# Formatting `city_id` to conform with the ids displayed on the Brazilian cesus files

# %%
data['city_id'] = data['city_id'].apply(lambda x: x.zfill(5))

# %% [markdown]
# ## Checking out a `unique_id` for each city

# %%
data[data['city_id'] == '00108']
# Out:
#      state state_id city_id city_name population_projection
# 1831    BA       29   00108    Abaíra                  9132
# 5583    DF       53   00108  Brasília               2789761

# %%
UNIQUE_IDS = data.loc[:,['state_id', 'city_id']]

for i in range(len(UNIQUE_IDS['state_id'])):
    UNIQUE_IDS.loc[i,'ids'] = '{}{}'.format(UNIQUE_IDS.loc[i,'state_id'],
                                              UNIQUE_IDS.loc[i,'city_id'])

UNIQUE_IDS.head()
# Out:
#   state_id city_id      ids
# 0       11   00015  1100015
# 1       11   00379  1100379
# 2       11   00403  1100403
# 3       11   00346  1100346
# 4       11   00023  1100023

# %%
len(set(UNIQUE_IDS['ids']))
# Out:
# 5570

# %%
UNIQUE_IDS.shape
# Out:
# (5584, 3)

# %%
brazilian_states = {'RO': 'rondonia',
                    'AC': 'acre',
                    'AM': 'amazonas',
                    'RR': 'roraima',
                    'PA': 'para',
                    'AP': 'amapa',
                    'TO': 'tocantis',
                    'MA': 'maranhao',
                    'PI': 'piaui',
                    'CE': 'ceara',
                    'RN': 'rio_grande_do_norte',
                    'PB': 'paraiba',
                    'PE': 'pernambuco',
                    'AL': 'alagoas',
                    'SE': 'sergipe',
                    'BA': 'bahia',
                    'MG': 'mina_gerais',
                    'ES': 'epirito_santo',
                    'RJ': 'rio_de_janeiro',
                    'SP': 'sao_paulo',
                    'PR': 'parana',
                    'SC': 'santa_catarina', 
                    'RS': 'rio_grande_do_sul',
                    'MS': 'mato_grosso_do_sul',
                    'MT': 'mato_grosso',
                    'GO': 'goias',
                    'DF': 'distrito_federal'}

census_link = "ftp.ibge.gov.br/Censos/Censo_Demografico_2010/resultados/total_populacao_{}.zip"

# %% [markdown]
# ## Gathering cities with @cuducos Brazilian Cities script
#
# @cuducos had already made a script with all Brazilian Cities and its code and state associated, here in [this repository](https://github.com/cuducos/brazilian-cities).
#
# We checked and it is the best way to get the cities in the right way.

# %%
from serenata_toolbox.datasets import fetch

fetch('2017-05-22-brazilian-cities.csv', '../data')
# Out:
# Downloading 2017-05-22-brazilian-cities.csv: 100%|██████████| 134K/134K [00:01<00:00, 97.1Kb/s]

# %%
brazilian_cities = pd.read_csv('../data/2017-05-22-brazilian-cities.csv')
brazilian_cities.head()
# Out:
#      code                 name state
# 0  520005      Abadia de Goiás    GO
# 1  310010  Abadia dos Dourados    MG
# 2  520010            Abadiânia    GO
# 3  150010           Abaetetuba    PA
# 4  310020               Abaeté    MG

# %%
brazilian_cities.shape
# Out:
# (5570, 3)

# %% [markdown]
# ## Normalizing its form
#
# It is necessary to normalize all information in order to use it to our necessities, so we managed to:
# - Lowercase all states
# - Remove all acentuation and normalize cities names
# - And for our case we remove spaces to generate the pattern we want

# %%
brazilian_cities['state'] = brazilian_cities['state'].apply(str.lower)

# %%
import unicodedata

def normalize_string(string):
    if isinstance(string, str):
        nfkd_form = unicodedata.normalize('NFKD', string.lower())
        return nfkd_form.encode('ASCII', 'ignore').decode('utf-8')

# %%
brazilian_cities['normalized_name'] = brazilian_cities['name'].apply(lambda x: normalize_string(x))
brazilian_cities['normalized_name'] = brazilian_cities['normalized_name'].apply(lambda x: x.replace(' ', ''))

# %%
brazilian_cities.head()
# Out:
#      code                 name state    normalized_name
# 0  520005      Abadia de Goiás    go      abadiadegoias
# 1  310010  Abadia dos Dourados    mg  abadiadosdourados
# 2  520010            Abadiânia    go          abadiania
# 3  150010           Abaetetuba    pa         abaetetuba
# 4  310020               Abaeté    mg             abaete

# %% [markdown]
# ## Getting all cities that are part of Transparency Portal
#
# There are some cities that we already know that have a page with transparency and open data. The main objective here is to find how many cities have that.
#
# Pattern: `{city}-{state}.portaltp.com.br`

# %%
portal_url = 'https://{}-{}.portaltp.com.br/'
brazilian_cities['transparency_portal_url'] = brazilian_cities.apply(lambda row: portal_url.format(
                                                                                        row['normalized_name'],
                                                                                        row['state']), axis=1)
brazilian_cities.head(20)
# Out:
#       code                 name state    normalized_name  \
# 0   520005      Abadia de Goiás    go      abadiadegoias
# 1   310010  Abadia dos Dourados    mg  abadiadosdourados
# 2   520010            Abadiânia    go          abadiania
# 3   150010           Abaetetuba    pa         abaetetuba
# 4   310020               Abaeté    mg             abaete
# 5   230010              Abaiara    ce            abaiara
# 6   290020                Abaré    ba              abare
# 7   410010               Abatiá    pr             abatia
# 8   290010               Abaíra    ba             abaira
# 9   420005        Abdon Batista    sc       abdonbatista
# 10  150013      Abel Figueiredo    pa     abelfigueiredo
# 11  420010         Abelardo Luz    sc        abelardoluz
# 12  310030           Abre Campo    mg          abrecampo
# 13  260005         Abreu e Lima    pe         abreuelima
# 14  170025          Abreulândia    to        abreulandia
# 15  310040              Acaiaca    mg            acaiaca
# 16  290030            Acajutiba    ba          acajutiba
# 17  230015              Acarape    ce            acarape
# 18  230020               Acaraú    ce             acarau
# 19  240010                Acari    rn              acari
#
#                           transparency_portal_url
# 0       https://abadiadegoias-go.portaltp.com.br/
# 1   https://abadiadosdourados-mg.portaltp.com.br/
# 2           https://abadiania-go.portaltp.com.br/
# 3          https://abaetetuba-pa.portaltp.com.br/
# 4              https://abaete-mg.portaltp.com.br/
# 5             https://abaiara-ce.portaltp.com.br/
# 6               https://abare-ba.portaltp.com.br/
# 7              https://abatia-pr.portaltp.com.br/
# 8              https://abaira-ba.portaltp.com.br/
# 9        https://abdonbatista-sc.portaltp.com.br/
# 10     https://abelfigueiredo-pa.portaltp.com.br/
# 11        https://abelardoluz-sc.portaltp.com.br/
# 12          https://abrecampo-mg.portaltp.com.br/
# 13         https://abreuelima-pe.portaltp.com.br/
# 14        https://abreulandia-to.portaltp.com.br/
# 15            https://acaiaca-mg.portaltp.com.br/
# 16          https://acajutiba-ba.portaltp.com.br/
# 17            https://acarape-ce.portaltp.com.br/
# 18             https://acarau-ce.portaltp.com.br/
# 19              https://acari-rn.portaltp.com.br/

# %% [markdown]
# (Getting all of the status code for each city might take a while so we added the prints only for feedback)

# %%
import requests
    
def get_status(url):
    try:
        print(requests.head(url).status_code)
        return requests.head(url).status_code
    except requests.ConnectionError:
        print(404)
        return 404

# %%
# %%time
colatina = brazilian_cities[brazilian_cities['code'] == 320150]['transparency_portal_url'].values[0]
statusOK = get_status(colatina)

abaete = brazilian_cities[brazilian_cities['code'] == 310020]['transparency_portal_url'].values[0]
statusNOK = get_status(abaete)
# Out:
# 200
# 404
# CPU times: user 64.3 ms, sys: 13.1 ms, total: 77.4 ms
# Wall time: 2.28 s

# %%
br_cities = brazilian_cities.loc[:10,:].copy()

# %%
# %%time
br_cities.loc[:,'status_code'] = br_cities.apply(lambda x: get_status(x['transparency_portal_url']), axis=1)
# Out:
# 404
# 404
# 404
# 404
# 404
# 404
# 200
# 404
# 200
# 404
# 404
# CPU times: user 128 ms, sys: 20.6 ms, total: 149 ms
# Wall time: 4.21 s

# %%
br_cities
# Out:
#       code                 name state    normalized_name  \
# 0   520005      Abadia de Goiás    go      abadiadegoias
# 1   310010  Abadia dos Dourados    mg  abadiadosdourados
# 2   520010            Abadiânia    go          abadiania
# 3   150010           Abaetetuba    pa         abaetetuba
# 4   310020               Abaeté    mg             abaete
# 5   230010              Abaiara    ce            abaiara
# 6   290020                Abaré    ba              abare
# 7   410010               Abatiá    pr             abatia
# 8   290010               Abaíra    ba             abaira
# 9   420005        Abdon Batista    sc       abdonbatista
# 10  150013      Abel Figueiredo    pa     abelfigueiredo
#
#                           transparency_portal_url  status_code
# 0       https://abadiadegoias-go.portaltp.com.br/          404
# 1   https://abadiadosdourados-mg.portaltp.com.br/          404
# 2           https://abadiania-go.portaltp.com.br/          404
# 3          https://abaetetuba-pa.portaltp.com.br/          404
# 4              https://abaete-mg.portaltp.com.br/          404
# 5             https://abaiara-ce.portaltp.com.br/          404
# 6               https://abare-ba.portaltp.com.br/          200
# 7              https://abatia-pr.portaltp.com.br/          404
# 8              https://abaira-ba.portaltp.com.br/          200
# 9        https://abdonbatista-sc.portaltp.com.br/          404
# 10     https://abelfigueiredo-pa.portaltp.com.br/          404

# %% [markdown]
# This will take too long considering we have 5570 cities to address.
#
# Let's try using [grequests](https://pypi.python.org/pypi/grequests).
#
# I know that we can find two different status code in the first 10 cities urls test. So let's use those 10 to test grequests ;)

# %%
import grequests

rs = (grequests.get(u) for u in list(br_cities['transparency_portal_url']))

# %%
def exception_handler(request, exception):
    return 404

responses = grequests.map(rs, exception_handler=exception_handler)

# %%
codes = [int(x) for x in br_cities['status_code'].values]

print(pd.unique(codes), pd.unique(responses))
# Out:
# [404 200] [404]

# %%
responses
# Out:
# [404, 404, 404, 404, 404, 404, 404, 404, 404, 404, 404]

# %% [markdown]
# The result above got me wondering where were those 200 statuses code we've seen before. I tested the code on the command line and they are there. So a little reasearch and I found that apparently it is not possible to run async tasks easily on a jupyter notebook [ref](http://ipywidgets.readthedocs.io/en/latest/examples/Widget%20Asynchronous.html).
#
# With that in mind we decided to write a script that generates the infomartion we want: Open Data url for each brazilian city

# %%
data = br_cities[br_cities['status_code'] == 404].copy().reset_index(drop=True)
data
# Out:
#      code                 name state    normalized_name  \
# 0  520005      Abadia de Goiás    go      abadiadegoias
# 1  310010  Abadia dos Dourados    mg  abadiadosdourados
# 2  520010            Abadiânia    go          abadiania
# 3  150010           Abaetetuba    pa         abaetetuba
# 4  310020               Abaeté    mg             abaete
# 5  230010              Abaiara    ce            abaiara
# 6  410010               Abatiá    pr             abatia
# 7  420005        Abdon Batista    sc       abdonbatista
# 8  150013      Abel Figueiredo    pa     abelfigueiredo
#
#                          transparency_portal_url  status_code
# 0      https://abadiadegoias-go.portaltp.com.br/          404
# 1  https://abadiadosdourados-mg.portaltp.com.br/          404
# 2          https://abadiania-go.portaltp.com.br/          404
# 3         https://abaetetuba-pa.portaltp.com.br/          404
# 4             https://abaete-mg.portaltp.com.br/          404
# 5            https://abaiara-ce.portaltp.com.br/          404
# 6             https://abatia-pr.portaltp.com.br/          404
# 7       https://abdonbatista-sc.portaltp.com.br/          404
# 8     https://abelfigueiredo-pa.portaltp.com.br/          404

# %% [markdown]
# There are some cities that we already know that have a page with transparency and open data but the pattern is different from the one above.
#
# Second Pattern: `cm{city}-{state}.portaltp.com.br`

# %%
portal_url = 'https://cm{}-{}.portaltp.com.br/'
data['transparency_portal_url'] = data.apply(lambda row: portal_url.format(
                                                                           row['normalized_name'],
                                                                           row['state']), axis=1)
data
# Out:
#      code                 name state    normalized_name  \
# 0  520005      Abadia de Goiás    go      abadiadegoias
# 1  310010  Abadia dos Dourados    mg  abadiadosdourados
# 2  520010            Abadiânia    go          abadiania
# 3  150010           Abaetetuba    pa         abaetetuba
# 4  310020               Abaeté    mg             abaete
# 5  230010              Abaiara    ce            abaiara
# 6  410010               Abatiá    pr             abatia
# 7  420005        Abdon Batista    sc       abdonbatista
# 8  150013      Abel Figueiredo    pa     abelfigueiredo
#
#                            transparency_portal_url  status_code
# 0      https://cmabadiadegoias-go.portaltp.com.br/          404
# 1  https://cmabadiadosdourados-mg.portaltp.com.br/          404
# 2          https://cmabadiania-go.portaltp.com.br/          404
# 3         https://cmabaetetuba-pa.portaltp.com.br/          404
# 4             https://cmabaete-mg.portaltp.com.br/          404
# 5            https://cmabaiara-ce.portaltp.com.br/          404
# 6             https://cmabatia-pr.portaltp.com.br/          404
# 7       https://cmabdonbatista-sc.portaltp.com.br/          404
# 8     https://cmabelfigueiredo-pa.portaltp.com.br/          404

# %% [markdown]
# We still need to update the status code column

# %%
# %%time
data.loc[:,'status_code'] = data.apply(lambda x: get_status(x['transparency_portal_url']), axis=1)
# Out:
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# 404
# CPU times: user 44.6 ms, sys: 12.1 ms, total: 56.8 ms
# Wall time: 118 ms

# %%
data
# Out:
#      code                 name state    normalized_name  \
# 0  520005      Abadia de Goiás    go      abadiadegoias
# 1  310010  Abadia dos Dourados    mg  abadiadosdourados
# 2  520010            Abadiânia    go          abadiania
# 3  150010           Abaetetuba    pa         abaetetuba
# 4  310020               Abaeté    mg             abaete
# 5  230010              Abaiara    ce            abaiara
# 6  410010               Abatiá    pr             abatia
# 7  420005        Abdon Batista    sc       abdonbatista
# 8  150013      Abel Figueiredo    pa     abelfigueiredo
#
#                            transparency_portal_url  status_code
# 0      https://cmabadiadegoias-go.portaltp.com.br/          404
# 1  https://cmabadiadosdourados-mg.portaltp.com.br/          404
# 2          https://cmabadiania-go.portaltp.com.br/          404
# 3         https://cmabaetetuba-pa.portaltp.com.br/          404
# 4             https://cmabaete-mg.portaltp.com.br/          404
# 5            https://cmabaiara-ce.portaltp.com.br/          404
# 6             https://cmabatia-pr.portaltp.com.br/          404
# 7       https://cmabdonbatista-sc.portaltp.com.br/          404
# 8     https://cmabelfigueiredo-pa.portaltp.com.br/          404

# %%
# study purposes
data.loc[8, 'status_code'] = 200
data
# Out:
#      code                 name state    normalized_name  \
# 0  520005      Abadia de Goiás    go      abadiadegoias
# 1  310010  Abadia dos Dourados    mg  abadiadosdourados
# 2  520010            Abadiânia    go          abadiania
# 3  150010           Abaetetuba    pa         abaetetuba
# 4  310020               Abaeté    mg             abaete
# 5  230010              Abaiara    ce            abaiara
# 6  410010               Abatiá    pr             abatia
# 7  420005        Abdon Batista    sc       abdonbatista
# 8  150013      Abel Figueiredo    pa     abelfigueiredo
#
#                            transparency_portal_url  status_code
# 0      https://cmabadiadegoias-go.portaltp.com.br/          404
# 1  https://cmabadiadosdourados-mg.portaltp.com.br/          404
# 2          https://cmabadiania-go.portaltp.com.br/          404
# 3         https://cmabaetetuba-pa.portaltp.com.br/          404
# 4             https://cmabaete-mg.portaltp.com.br/          404
# 5            https://cmabaiara-ce.portaltp.com.br/          404
# 6             https://cmabatia-pr.portaltp.com.br/          404
# 7       https://cmabdonbatista-sc.portaltp.com.br/          404
# 8     https://cmabelfigueiredo-pa.portaltp.com.br/          200

# %%
data.loc[data['status_code'] == 404, 'transparency_portal_url'] = None
data
# Out:
#      code                 name state    normalized_name  \
# 0  520005      Abadia de Goiás    go      abadiadegoias
# 1  310010  Abadia dos Dourados    mg  abadiadosdourados
# 2  520010            Abadiânia    go          abadiania
# 3  150010           Abaetetuba    pa         abaetetuba
# 4  310020               Abaeté    mg             abaete
# 5  230010              Abaiara    ce            abaiara
# 6  410010               Abatiá    pr             abatia
# 7  420005        Abdon Batista    sc       abdonbatista
# 8  150013      Abel Figueiredo    pa     abelfigueiredo
#
#                         transparency_portal_url  status_code
# 0                                          None          404
# 1                                          None          404
# 2                                          None          404
# 3                                          None          404
# 4                                          None          404
# 5                                          None          404
# 6                                          None          404
# 7                                          None          404
# 8  https://cmabelfigueiredo-pa.portaltp.com.br/          200

# %%
br_cities.loc[br_cities['status_code'] == 404, 'transparency_portal_url'] = None
br_cities
# Out:
#       code                 name state    normalized_name  \
# 0   520005      Abadia de Goiás    go      abadiadegoias
# 1   310010  Abadia dos Dourados    mg  abadiadosdourados
# 2   520010            Abadiânia    go          abadiania
# 3   150010           Abaetetuba    pa         abaetetuba
# 4   310020               Abaeté    mg             abaete
# 5   230010              Abaiara    ce            abaiara
# 6   290020                Abaré    ba              abare
# 7   410010               Abatiá    pr             abatia
# 8   290010               Abaíra    ba             abaira
# 9   420005        Abdon Batista    sc       abdonbatista
# 10  150013      Abel Figueiredo    pa     abelfigueiredo
#
#                transparency_portal_url  status_code
# 0                                 None          404
# 1                                 None          404
# 2                                 None          404
# 3                                 None          404
# 4                                 None          404
# 5                                 None          404
# 6    https://abare-ba.portaltp.com.br/          200
# 7                                 None          404
# 8   https://abaira-ba.portaltp.com.br/          200
# 9                                 None          404
# 10                                None          404

# %%
unnecessary_columns = ['normalized_name', 'status_code']
br_cities = pd.merge(br_cities.drop(unnecessary_columns, axis=1),
                  data.drop(unnecessary_columns, axis=1),
                  on=['code', 'name', 'state'], how='left')

br_cities['transparency_portal_url'] = br_cities \
      .apply(lambda row: row['transparency_portal_url_x'] or row['transparency_portal_url_y'], axis=1)
    
unnecessary_columns = ['transparency_portal_url_x', 'transparency_portal_url_y']
br_cities = br_cities.drop(unnecessary_columns, axis=1)
br_cities
# Out:
#       code                 name state  \
# 0   520005      Abadia de Goiás    go
# 1   310010  Abadia dos Dourados    mg
# 2   520010            Abadiânia    go
# 3   150010           Abaetetuba    pa
# 4   310020               Abaeté    mg
# 5   230010              Abaiara    ce
# 6   290020                Abaré    ba
# 7   410010               Abatiá    pr
# 8   290010               Abaíra    ba
# 9   420005        Abdon Batista    sc
# 10  150013      Abel Figueiredo    pa
#
#                          transparency_portal_url
# 0                                           None
# 1                                           None
# 2                                           None
# 3                                           None
# 4                                           None
# 5                                           None
# 6              https://abare-ba.portaltp.com.br/
# 7                                           None
# 8             https://abaira-ba.portaltp.com.br/
# 9                                           None
# 10  https://cmabelfigueiredo-pa.portaltp.com.br/

# %% [markdown]
# # Conclusions
#
# After all that study, we find that in that pattern of transparency portals list there are already 279 cities, from them 19 are returning an Internal Server Error (Status Code: 5XX).
#
# It is something like 5% of all Brazilian existing cities!
#
# Below we have a table with all those cities with portals ;)

# %%
with_tp_portal = pd.read_csv('../data/2017-05-30-cities_with_tp_portal.csv')
with_tp_portal.shape
# Out:
# (279, 5)

# %%
with_tp_portal
# Out:
#        code                       name state  \
# 0    290020                      Abaré    BA
# 1    290010                     Abaíra    BA
# 2    320010             Afonso Cláudio    ES
# 3    320020                     Alegre    ES
# 4    320030             Alfredo Chaves    ES
# 5    310170                   Almenara    MG
# 6    320035              Alto Rio Novo    ES
# 7    320040                   Anchieta    ES
# 8    290160                      Antas    BA
# 9    320050                     Apiacá    ES
# 10   290200                    Aracatu    BA
# 11   290210                      Araci    BA
# 12   320060                    Aracruz    ES
# 13   290225                    Arataca    BA
# 14   310340                    Araçuaí    MG
# 15   310445                 Aricanduva    MG
# 16   320070            Atilio Vivacqua    ES
# 17   290240              Aurelino Leal    BA
# 18   320080               Baixo Guandu    ES
# 19   310500                     Baldim    MG
# 20   310520                   Bandeira    MG
# 21   320090     Barra de São Francisco    ES
# 22   290330                Barro Preto    BA
# 23   290340                   Belmonte    BA
# 24   290350                 Belo Campo    BA
# 25   310650                     Berilo    MG
# 26   310665                    Berizal    MG
# 27   320100              Boa Esperança    ES
# 28   290370                   Boa Nova    BA
# 29   310720           Bocaina de Minas    MG
# ..      ...                        ...   ...
# 249  320495         São Roque do Canaã    ES
# 250  316450  São Sebastião do Maranhão    MG
# 251  316790                  Tabuleiro    MG
# 252  316800                 Taiobeiras    MG
# 253  293135        Teixeira de Freitas    BA
# 254  316870                    Timóteo    MG
# 255  293180                   Tremedal    BA
# 256  316930              Três Corações    MG
# 257  316935                Três Marias    MG
# 258  293220                   Ubaitaba    BA
# 259  293210                     Ubaíra    BA
# 260  293250                        Una    BA
# 261  293270                    Uruçuca    BA
# 262  317057              Vargem Alegre    MG
# 263  320503                Vargem Alta    ES
# 264  320506    Venda Nova do Imigrante    ES
# 265  317107                  Veredinha    MG
# 266  317115              Vermelho Novo    MG
# 267  320510                      Viana    ES
# 268  320515                 Vila Pavão    ES
# 269  320517               Vila Valério    ES
# 270  320520                 Vila Velha    ES
# 271  317180               Virginópolis    MG
# 272  317190                Virgolândia    MG
# 273  293330       Vitória da Conquista    BA
# 274  317130                     Viçosa    MG
# 275  293340                     Wagner    BA
# 276  310060                   Água Boa    MG
# 277  320016         Água Doce do Norte    ES
# 278  320013               Águia Branca    ES
#
#                                transparency_portal_url  status_code
# 0                    https://abare-ba.portaltp.com.br/          200
# 1                   https://abaira-ba.portaltp.com.br/          200
# 2            https://afonsoclaudio-es.portaltp.com.br/          200
# 3                   https://alegre-es.portaltp.com.br/          200
# 4            https://alfredochaves-es.portaltp.com.br/          200
# 5                 https://almenara-mg.portaltp.com.br/          200
# 6              https://altorionovo-es.portaltp.com.br/          200
# 7                 https://anchieta-es.portaltp.com.br/          200
# 8                    https://antas-ba.portaltp.com.br/          200
# 9                   https://apiaca-es.portaltp.com.br/          200
# 10                 https://aracatu-ba.portaltp.com.br/          200
# 11                   https://araci-ba.portaltp.com.br/          200
# 12                 https://aracruz-es.portaltp.com.br/          200
# 13                 https://arataca-ba.portaltp.com.br/          200
# 14               https://cmaracuai-mg.portaltp.com.br/          200
# 15              https://aricanduva-mg.portaltp.com.br/          200
# 16        https://cmatiliovivacqua-es.portaltp.com.br/          200
# 17            https://aurelinoleal-ba.portaltp.com.br/          200
# 18             https://baixoguandu-es.portaltp.com.br/          200
# 19                  https://baldim-mg.portaltp.com.br/          200
# 20                https://bandeira-mg.portaltp.com.br/          200
# 21     https://barradesaofrancisco-es.portaltp.com.br/          200
# 22              https://barropreto-ba.portaltp.com.br/          200
# 23                https://belmonte-ba.portaltp.com.br/          200
# 24               https://belocampo-ba.portaltp.com.br/          200
# 25                https://cmberilo-mg.portaltp.com.br/          200
# 26                 https://berizal-mg.portaltp.com.br/          200
# 27            https://boaesperanca-es.portaltp.com.br/          200
# 28                 https://boanova-ba.portaltp.com.br/          200
# 29        https://cmbocainademinas-mg.portaltp.com.br/          500
# ..                                                 ...          ...
# 249        https://saoroquedocanaa-es.portaltp.com.br/          200
# 250  https://saosebastiaodomaranhao-mg.portaltp.com...          200
# 251            https://cmtabuleiro-mg.portaltp.com.br/          200
# 252             https://taiobeiras-mg.portaltp.com.br/          200
# 253      https://teixeiradefreitas-ba.portaltp.com.br/          200
# 254                https://timoteo-mg.portaltp.com.br/          200
# 255               https://tremedal-ba.portaltp.com.br/          200
# 256           https://trescoracoes-mg.portaltp.com.br/          200
# 257             https://tresmarias-mg.portaltp.com.br/          200
# 258               https://ubaitaba-ba.portaltp.com.br/          200
# 259               https://cmubaira-ba.portaltp.com.br/          200
# 260                    https://una-ba.portaltp.com.br/          200
# 261                https://urucuca-ba.portaltp.com.br/          200
# 262           https://vargemalegre-mg.portaltp.com.br/          200
# 263             https://vargemalta-es.portaltp.com.br/          200
# 264   https://vendanovadoimigrante-es.portaltp.com.br/          200
# 265              https://veredinha-mg.portaltp.com.br/          200
# 266           https://vermelhonovo-mg.portaltp.com.br/          500
# 267                  https://viana-es.portaltp.com.br/          200
# 268              https://vilapavao-es.portaltp.com.br/          200
# 269            https://vilavalerio-es.portaltp.com.br/          200
# 270            https://cmvilavelha-es.portaltp.com.br/          200
# 271         https://cmvirginopolis-mg.portaltp.com.br/          200
# 272            https://virgolandia-mg.portaltp.com.br/          200
# 273     https://vitoriadaconquista-ba.portaltp.com.br/          200
# 274               https://cmvicosa-mg.portaltp.com.br/          200
# 275                 https://wagner-ba.portaltp.com.br/          200
# 276                https://aguaboa-mg.portaltp.com.br/          200
# 277        https://aguadocedonorte-es.portaltp.com.br/          200
# 278            https://aguiabranca-es.portaltp.com.br/          200
#
# [279 rows x 5 columns]
